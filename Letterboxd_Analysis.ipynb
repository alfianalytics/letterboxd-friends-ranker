# %% [markdown]
# <a href="https://colab.research.google.com/github/ilmuneraka/letterboxd-friends-ranker/blob/main/Letterboxd_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

DOMAIN = "https://letterboxd.com"

# %% [markdown]
# # Scraping with BeautifulSoup

# %%
# we will try to get html of my letterboxd page
username = "cacingpincang"
url = DOMAIN + "/" + username + "/films/"
url_page = requests.get(url)
soup = BeautifulSoup(url_page.content, 'html.parser')

# %%
# we will take a look at the html
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7 ]> <html lang="en" class="ie6 lte9 lte8 lte7 lte6 no-js"> <![endif]-->
# <!--[if IE 7 ]>    <html lang="en" class="ie7 lte9 lte8 lte7 no-js"> <![endif]-->
# <!--[if IE 8 ]>    <html lang="en" class="ie8 lte9 lte8 no-js"> <![endif]-->
# <!--[if IE 9 ]>    <html lang="en" class="ie9 lte9 no-js"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--> <html class="no-mobile no-js" id="html" lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=1024" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="Alfian Hakim’s films" name="description"/>
# <meta content="https://letterboxd.com/cacingpincang/films/" property="og:url"/>
# <meta content="Alfian Hakim’s films" property="og:title"/>
# <meta content="Alfian Hakim’s films" property="og:description"/>
# <meta content="https://s.ltrbxd.com/static/img/default-share.e38c5d62.png" property="og:image"/>
# <meta content="Letterboxd" name="application-name"/>
# <meta content="#445566" name="theme-color"/>
# <meta content="#445566" name="msapplication-TileColor"/>
# <meta content="app-id=1054271011, affiliate-data=11l5KW, app-argument=https://letterboxd.com/cacingpincang/films/" name="apple-itunes-app"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <title>‎Alfian Hakim’s films • Letterboxd</title>
# <script>
# 		window.dataLayer = window.dataLayer || [];
# 		window.gtag = window.gtag || function () {
# 			dataLayer.push(arguments);
# 		};
# 		function ga() {}
#
# 		// Default consent to 'denied'.
# 		gtag('consent', 'default', {
# 			'analytics_storage': 'denied',
# 			'ad_storage': 'denied',
# 		});
# 	</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-D3ECBB4D7L"></script>
# <script>
# 		window.dataLayer = window.dataLayer || [];
# 		window.gtag = window.gtag || function () {
# 			dataLayer.push(arguments);
# 		};
# 		gtag('js', new Date());
#
# 		var analytic_params = {};
#
#
# 		analytic_params['user_type'] = 'Visitor';
# 		analytic_params['template'] = '/object/person/films-watched';
#
#
#
# 		if (analytic_params.member_type) {
# 			gtag('set', 'user_properties', {
# 				member_type: analytic_params.member_type,
# 			});
# 			delete analytic_params.member_type;
# 		}
# 		var config = {
# 			...analytic_params,
# 			'cookie_domain': 'letterboxd.com',
# 			'optimize_id': 'GTM-TB8HSDN',
# 		};
# 		gtag('config', 'G-D3ECBB4D7L', config);
# 	</script>
# <script>
# 		var isMobile = false,
# 			isMobileOptimised = true,
# 			renderMobile = false,
# 			useStaticFonts = false,
# 			disableFrameProtection = false,
# 			baseURL = "",
# 			successMessages = [],
# 			errorMessages = [],
# 			stickyMessages = [],
# 			globals = {
# 			autoAddFilm: false
# 				, spinners: {
# 					ajax_242d35: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.fda24f88.gif',
# 					spinner_12_2C3641: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.fda24f88.gif',
# 					spinner_14_20272f: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.fda24f88.gif',
# 					spinner_16_161B21: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.fda24f88.gif'
# 				}
# 			},
# 			supermodelCSRF = "",
# 			gRecaptchaKey = '6Le3mMIUAAAAAEXbwZ7M1R5jEv0V5xbvj7bgXq2g',
# 			person = {
# 				username: ""
# 				, loggedIn: false
#
# 				, showAds: true
# 				, role: "guest"
# 				, hasExtendedServiceFilters: false
# 				, canBulkAddToLists: false
# 				, canFilterOwned: false
# 				, hasHqRole: false
# 				, canHaveHqDashboard: false
# 				, hasMemberStatistics: false
# 				, blockedMembers: []
# 				, showAdultContent: false
# 				, validated: null
# 				, trusted: false
# 				, hasBlocked : function(member) { for (var i = 0; i !== person.blockedMembers.length; i++) {if (person.blockedMembers[i] === member) return true;} return false; }
# 				, viewingTags: []
# 				, hasMoreTags: true
# 				, getCustomPoster : function(filmId) { return null; }
# 			},
# 			disableAds = false;
#
#
#
# supermodelCSRF = "b44a55dc6d5e01d92f2d";
#
#
#
#
#
#
#
#
# 			if ( screen.width < 768 ) {
# 				var date = new Date();
# 				var maxAge = 365 * 24 * 60 * 60;
# 				date.setTime(date.getTime() + maxAge * 1000);
# 				var expires = '; expires=' + date.toUTCString();
# 				document.cookie = "useMobileSite=yes" + expires + "; path=/; maxAge=" + maxAge;
# 				if ( document.cookie && document.cookie.indexOf("useMobileSite=yes") >= 0 ) {
# 					window.location.reload(true);
# 				} else {
# 					// No cookies.  No Mobile version.
# 				}
# 			}
#
#
# 		var isWindows = navigator.platform.toUpperCase().indexOf('WIN') >= 0; // Detect windows platform
# 		if (isWindows) { document.documentElement.classList.add('is-windows'); }
#
#
# 	</script>
# <script>
# 		window.ramp = window.ramp || {};
# 		window.ramp.que = window.ramp.que || [];
# 		window.ramp.passiveMode = false;
# 		window.ramp.forcePath = '';
# 		window.ramp.custom_tags = [
# 			'',
# 			'',
# 			'',
# 			'',
# 			''
# 		];
# 	</script>
# <script src="//cdn.intergient.com/1024338/72804/ramp_config.js"></script>
# <script>
# 		window._pwGA4PageviewId = ''.concat(Date.now());
# 		window.dataLayer = window.dataLayer || [];
# 		window.gtag = window.gtag || function () {
# 			dataLayer.push(arguments);
# 		};
# 		gtag('js', new Date());
# 		gtag('config', 'G-L0W7RDZXX3', { 'send_page_view': false });
# 		gtag(
# 			'event',
# 			'ramp_js',
# 			{
# 				'send_to': 'G-L0W7RDZXX3',
# 				'pageview_id': window._pwGA4PageviewId
# 			}
# 		);
# 	</script>
# <link href="/manifest.json" rel="manifest"/>
# <link href="/humans.txt" rel="author" type="text/plain"/>
# <link color="#445566" href="https://s.ltrbxd.com/static/img/icons/letterboxd-decal-l-16px.5fe24c7d.svg" rel="mask-icon"/>
# <link href="https://s.ltrbxd.com/static/img/icons/touch-icon-192x192.257b84e7.png" rel="shortcut icon" sizes="196x196"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/static/opensearch.xml" rel="search" title="Letterboxd" type="application/opensearchdescription+xml"/>
# <!--[if lte IE 9 ]>
# 		<link href="https://s.ltrbxd.com/static/css/ie9-1.min.33b3ae5e.css" rel="stylesheet" media="screen, projection"/>
# 		<link href="https://s.ltrbxd.com/static/css/ie9-2.min.b76506f1.css" rel="stylesheet" media="screen, projection"/>
# 	<![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <link href="https://s.ltrbxd.com/static/css/main.min.119b8332.css" media="screen, projection" rel="stylesheet"/>
# <!--<![endif]-->
# <!--[if lte IE 6]><script>location.replace("/errors/ie6");</script><![endif]-->
# <!--[if IE 7]><script>location.replace("/errors/ie7");</script><![endif]-->
# <!--[if IE 8]><script>location.replace("/errors/ie8");</script><![endif]-->
# <!--[if IE 9]><script>location.replace("/errors/ie9");</script><![endif]-->
# <link href="https://s.ltrbxd.com/static/css/desktop.min.1c7835d9.css" media="screen, projection" rel="stylesheet"/>
# <script src="https://s.ltrbxd.com/static/js/main.min.5620f639.js"></script>
# <script>
# 		if ( $.cookie("letterboxd.admin.signed.in") === person.username ) {
# 			successMessages.push("You are signed in as " + person.username);
# 			$(function(){$("#header, #content, body").css("background","#543");});
# 		}
# 	</script>
# </head>
# <body class="films-watched wide small-poster-grid" data-owner="cacingpincang">
# <script>
# var mainMenu = [];
#
#
# 	mainMenu.push({
# 		"id": 1,
# 		"url": "/sign-in/",
# 		"name": "Sign In",
# 		"cssClassCode": "sign-in-menu",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": true,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 2,
# 		"url": "/create-account/",
# 		"name": "Create Account",
# 		"cssClassCode": "create-account-menu",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 3,
# 		"url": "/",
# 		"name": "Home",
# 		"cssClassCode": "person-home",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": true,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 4,
# 		"url": "/activity/",
# 		"name": "Activity",
# 		"cssClassCode": "main-nav-activity",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": true,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "Activity",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 5,
# 		"url": "/films/",
# 		"name": "Films",
# 		"cssClassCode": "films-page main-nav-films",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 6,
# 		"url": "/lists/",
# 		"name": "Lists",
# 		"cssClassCode": "lists-page main-nav-lists",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 7,
# 		"url": "/members/",
# 		"name": "Members",
# 		"cssClassCode": "main-nav-people",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 8,
# 		"url": "/journal/",
# 		"name": "Journal",
# 		"cssClassCode": "main-nav-journal",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 9,
# 		"url": "/search/",
# 		"name": "Search results",
# 		"cssClassCode": "",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": true,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
# </script>
# <header class="site-header js-hide-in-app" data-allow-user-to-add-all-films-to-a-list="true" id="header">
# <div class="site-header-bg"></div>
# <section>
# <h1 class="site-logo"><a class="logo replace" href="/">Letterboxd — Your life in film</a></h1>
# <div class="react-component" data-component-class="globals.comps.NavComponent"></div>
# <form action="#" autocapitalize="off" autocorrect="off" class="signin signin-form js-header-signin-form js-signin" data-recaptcha-action="signin" data-url="/user/login.do" id="signin" method="post" novalidate="novalidate">
# <input name="__csrf" type="hidden" value="placeholder"/>
# <fieldset class="fieldset">
# <div class="fields">
# <div class="col">
# <label for="username">Username or Email</label>
# <input autocomplete="email" class="field signin-field" data-focus-control="signingIn" id="username" inputmode="email" name="username" tabindex="1" type="email" value=""/>
# </div>
# <div class="col">
# <label for="password">Password</label>
# <input autocomplete="current-password" class="field signin-field" id="password" name="password" tabindex="2" type="password" value=""/>
# </div>
# <div class="signin-actions">
# <label class="option-label -checkbox -small" for="remember">
# <input class="checkbox" id="remember" name="remember" tabindex="3" type="checkbox" value="true"/><i class="substitute"></i>
# <span class="focus">Remember<span class="mob-hide"> me</span></span>
# </label>
# <p class="reset" tabindex="5"><a class="reset-password-link" href="/user/request-password-reset" target="_top">Forgotten<span class="elongated"> password</span>?</a></p>
# </div>
# <div class="col buttons">
# <div class="button-container"><input class="button -action button-green" tabindex="4" type="submit" value="Sign in"/><i></i></div>
# <div class="close js-close-signin">×</div>
# </div>
# </div>
# </fieldset>
# <div class="errormessage" id="signin-message"></div>
# </form>
# <form action="/search/" autocorrect="off" class="js-search-form search-form" id="search" method="get">
# <input autocomplete="false" name="hidden" style="display:none;" type="text"/>
# <fieldset>
# <label class="hidden" for="search-q">Search:</label>
# <input class="field -borderless" data-lpignore="true" id="search-q" inputmode="search" name="q" type="text" value=""/>
# <input class="action" type="submit" value="Search"/>
# </fieldset>
# </form>
# </section>
# </header>
# <div class="site-body" id="content">
# <div class="content-wrap">
# <section class="js-profile-header -is-mini-nav" data-person="cacingpincang" id="profile-header">
# <nav class="profile-navigation">
# <div class="profile-mini-person">
# <a class="avatar -a24" href="/cacingpincang/"> <img alt="Alfian Hakim" height="24" src="https://a.ltrbxd.com/resized/avatar/upload/5/3/2/4/1/6/7/shard/avtr-0-48-0-48-crop.jpg?v=0757d28c82" width="24"/> </a>
# <h1 class="title-3"><a href="/cacingpincang/">Alfian Hakim</a></h1>
# </div>
# <ul class="navlist">
# <li class="navitem hide-for-owner" data-owner="cacingpincang"><a class="navlink" href="/cacingpincang/activity/">Activity</a></li>
# <li class="navitem show-for-owner" data-owner="cacingpincang"><a class="navlink" href="/activity/">Activity</a></li>
# <li class="navitem -active" data-owner="cacingpincang"><a class="navlink" href="/cacingpincang/films/">Films</a></li>
# <li class="navitem" data-owner="cacingpincang"><a class="navlink" href="/cacingpincang/films/diary/">Diary</a></li>
# <li class="navitem" data-owner="cacingpincang"><a class="navlink" href="/cacingpincang/films/reviews/">Reviews</a></li>
# <li class="navitem" data-owner="cacingpincang"><a class="navlink" href="/cacingpincang/watchlist/">Watchlist</a></li>
# <li class="navitem show-for-owner" data-owner="cacingpincang"><a class="navlink" href="/cacingpincang/lists/">Lists</a></li>
# <li class="navitem" data-owner="cacingpincang"><a class="navlink" href="/cacingpincang/likes/">Likes</a></li>
# <li class="navitem show-for-owner" data-owner="cacingpincang"><a class="navlink" href="/cacingpincang/tags/">Tags</a></li>
# <li class="navitem" data-owner="cacingpincang"><a class="navlink" href="/cacingpincang/following/">Network</a></li>
# <li class="navitem show-when-logged-in hide-for-owner" data-owner="cacingpincang"><a class="navlink" href="/pro/gift/cacingpincang/">Gift Pro</a></li>
# <li class="navitem -rss">
# <a class="has-icon icon-16 icon-rss tooltip" href="/cacingpincang/rss/" title="RSS feed">
# <span class="_sr-only">RSS feed for Alfian</span>
# </a>
# </li>
# </ul>
# </nav>
# </section>
# <div class="cols-2 overflow">
# <section class="section col-main overflow">
# <div class="tabbed" id="content-nav"> <section class="sub-nav-wrapper"><ul class="sub-nav"> <li class=" selected"><a class="tooltip" href="/cacingpincang/films/" title="226 films">Watched</a></li> <li class=""><a class="tooltip" href="/cacingpincang/films/diary/" title="169 films">Diary</a></li> <li class=""><a class="tooltip" href="/cacingpincang/films/reviews/" title="22 films">Reviews</a></li> </ul></section> <div class="sorting-selects has-hide-toggle"> <section class="grid-toggle-menu mob-hide"> <ul> <li class="selected"><a class="grid-toggle ir s grid-toggle-small" data-toggle="large" href="/cacingpincang/films/">Small</a></li> <li><a class="grid-toggle ir s grid-toggle-large" data-toggle="small" href="/cacingpincang/films/size/large/">Large</a></li> </ul> </section> <section class="smenu-wrapper hide-toggle-menu"> <div class="smenu"> <label><span class="ir s hide-toggle-icon">Visibility Filters</span><i class="ir s icon"></i></label> <ul class="smenu-menu" id="hide-toggle-menu"> <li class="divider-line-below"><a class="item js-film-filter-remover" href="#">Remove filters</a></li> <li class="js-account-filters"> <label class="option-label -toggle -small switch-control js-fade-toggle"> <span class="label">Fade watched films</span> <input checked="checked" class="checkbox" role="switch" type="checkbox"/><span class="state"><span class="track"><span class="handle"></span></span></span> </label> </li> <li class="js-account-filters"> <label class="option-label -toggle -small switch-control js-custom-poster-toggle" data-action="/ajax/poster-mode/"> <span class="label">Show custom posters</span> <input checked="checked" class="checkbox" role="switch" type="checkbox"/><span class="state"><span class="track"><span class="handle"></span></span></span> </label> </li> <li class="divider-line js-account-filters"> <span class="smenu-sublabel -uppercase">Custom posters</span> <div aria-label="Change custom poster visibility" class="segmented-control -small custom-poster-control js-custom-poster-control" data-action="/ajax/poster-mode/" role="group"> <div class="options"> <button class="option" data-js-trigger="option" data-value="All" type="button">Any</button> <button class="option" data-js-trigger="option" data-value="Theirs" type="button">Theirs</button> <button class="option" data-js-trigger="option" data-value="Yours" type="button">Yours</button> <button class="option" data-js-trigger="option" data-value="None" type="button">None</button> </div> </div> </li> <li class="divider-line js-account-filters"> <span class="smenu-sublabel -uppercase">Account Filters</span> <ul> <li class="js-film-filter" data-category="watched" data-type="show"><a class="item" href="#"><i class="ir s icon"></i>Show watched films</a></li> <li class="js-film-filter" data-category="watched" data-type="hide"><a class="item" href="#"><i class="ir s icon"></i>Hide watched films</a></li> <li class="js-film-filter divider-line -inset" data-category="liked" data-type="show"><a class="item" href="#"><i class="ir s icon"></i>Show liked films</a></li> <li class="js-film-filter" data-category="liked" data-type="hide"><a class="item" href="#"><i class="ir s icon"></i>Hide liked films</a></li> <li class="js-film-filter divider-line -inset" data-category="rated" data-type="show"><a class="item" href="#"><i class="ir s icon"></i>Show rated films</a></li> <li class="js-film-filter" data-category="rated" data-type="hide"><a class="item" href="#"><i class="ir s icon"></i>Hide rated films</a></li> <li class="js-film-filter divider-line -inset" data-category="logged" data-type="show"><a class="item" href="#"><i class="ir s icon"></i>Show logged films</a></li> <li class="js-film-filter" data-category="logged" data-type="hide"><a class="item" href="#"><i class="ir s icon"></i>Hide logged films</a></li> <li class="js-film-filter divider-line -inset" data-category="rewatched" data-type="show"><a class="item" href="#"><i class="ir s icon"></i>Show rewatched films</a></li> <li class= ...
# <section class="smenu-wrapper"> <div class="smenu"> <label>Service<i class="ir s icon"></i></label> <ul class="smenu-menu" data-upgrade-url="/pro/" id="services-menu"> <li class="availability- smenu-subselected"> <span class="selected"> All films </span> </li> <li class="divider-line availability-fandango"> <a class="item" href="/cacingpincang/films/on/fandango-us/"> Fandango US </a> </li> <li class="availability-amazon"> <a class="item" href="/cacingpincang/films/on/amazon-usa/"> Amazon US </a> </li> <li class="availability-amazon-video"> <a class="item" href="/cacingpincang/films/on/amazon-video-us/"> Amazon Video US </a> </li> <li class="availability-apple-tv-plus"> <a class="item" href="/cacingpincang/films/on/apple-tv-plus-us/"> Apple TV Plus US </a> </li> <li class="availability-apple-itunes"> <a class="item" href="/cacingpincang/films/on/apple-itunes-us/"> iTunes US </a> </li> <li class="note divider-line -upgrade"> <p>Upgrade to a <a href="/pro/">Letterboxd <span class="badge -pro -small">Pro</span></a> account to add your favorite services to this list—including any service and country pair listed on JustWatch—and to enable one-click filtering by all your favorites.</p></li> <li><a class="item item-small" href="https://www.justwatch.com" rel="noopener noreferrer" target="_blank"><small>Powered by JustWatch</small></a></li> </ul> </div> </section>
# <section class="smenu-wrapper"> <div class="smenu"> <label> Genre<i class="ir s icon"></i> </label> <ul class="smenu-menu"> <li class="smenu-subselected"><span class="selected">Any genre</span></li> <li class="divider-line"> <ul> <li class=""><a class="item" href="/cacingpincang/films/genre/action/"><i class="ir s icon"></i>Action</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/adventure/"><i class="ir s icon"></i>Adventure</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/animation/"><i class="ir s icon"></i>Animation</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/comedy/"><i class="ir s icon"></i>Comedy</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/crime/"><i class="ir s icon"></i>Crime</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/documentary/"><i class="ir s icon"></i>Documentary</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/drama/"><i class="ir s icon"></i>Drama</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/family/"><i class="ir s icon"></i>Family</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/fantasy/"><i class="ir s icon"></i>Fantasy</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/history/"><i class="ir s icon"></i>History</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/horror/"><i class="ir s icon"></i>Horror</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/music/"><i class="ir s icon"></i>Music</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/mystery/"><i class="ir s icon"></i>Mystery</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/romance/"><i class="ir s icon"></i>Romance</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/science-fiction/"><i class="ir s icon"></i>Science Fiction</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/thriller/"><i class="ir s icon"></i>Thriller</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/tv-movie/"><i class="ir s icon"></i>TV Movie</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/war/"><i class="ir s icon"></i>War</a></li> <li class=""><a class="item" href="/cacingpincang/films/genre/western/"><i class="ir s icon"></i>Western</a></li> </ul> </li> </ul> </div> </section> <section class="smenu-wrapper"> <div class="smenu"> <label class="x"> Decade<i class="ir s icon"></i> </label> <ul class="smenu-menu"> <li class="smenu-subselected"><span class="selected">Any decade</span></li> <li class="divider-line "><a class="item" href="/cacingpincang/films/decade/2020s/">2020s</a></li> <li class=""><a class="item" href="/cacingpincang/films/decade/2010s/">2010s</a></li> <li class=""><a class="item" href="/cacingpincang/films/decade/2000s/">2000s</a></li> <li class=""><a class="item" href="/cacingpincang/films/decade/1990s/">1990s</a></li> <li class=""><a class="item" href="/cacingpincang/films/decade/1980s/">1980s</a></li> <li class=""><a class="item" href="/cacingpincang/films/decade/1970s/">1970s</a></li> <li class=""><a class="item" href="/cacingpincang/films/decade/1960s/">1960s</a></li> <li class=""><a class="item" href="/cacingpincang/films/decade/1950s/">1950s</a></li> <li class=""><a class="item" href="/cacingpincang/films/decade/1940s/">1940s</a></li> <li class=""><a class="item" href="/cacingpincang/films/decade/1930s/">1930s</a></li> <li class=""><a class="item" href="/cacingpincang/films/decade/1920s/">1920s</a></li> <li class=""><a class="item" href="/cacingpincang/films/decade/1910s/">1910s</a></li> <li class=""><a class="item" href="/cacingpincang/films/decade/1900s/">1900s</a></li> <li class=""><a class="item" href="/cacingpincang/films/decade/1890s/">1890s</a></li> <li class=""><a class="item" href="/cacingpincang/films/decade/1880s/">1880s</a></li> <li class=""><a class="item" href="/cacingpinc ...
# <ul class="poster-list -p70 -grid film-list clear">
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-842221 linked-film-poster" data-cache-busting-key="037d4721" data-film-id="842221" data-film-slug="/film/a-man-called-otto/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/a-man-called-otto/image-150/" data-show-menu="true" data-target-link="/film/a-man-called-otto/" data-target-link-target=""> <img alt="A Man Called Otto" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-8">★★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-242285 linked-film-poster" data-cache-busting-key="d60f4abc" data-film-id="242285" data-film-slug="/film/puss-in-boots-the-last-wish/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/puss-in-boots-the-last-wish/image-150/" data-show-menu="true" data-target-link="/film/puss-in-boots-the-last-wish/" data-target-link-target=""> <img alt="Puss in Boots: The Last Wish" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata -rated-and-liked"> <span class="rating -tiny -darker rated-10">★★★★★</span> <span class="like has-icon icon-liked icon-16"><span class="icon"></span></span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-521323 linked-film-poster" data-cache-busting-key="8e7be729" data-film-id="521323" data-film-slug="/film/the-menu-2022/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/the-menu-2022/image-150/" data-show-menu="true" data-target-link="/film/the-menu-2022/" data-target-link-target=""> <img alt="The Menu" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-8">★★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-586723 linked-film-poster" data-cache-busting-key="0c10a16c" data-film-id="586723" data-film-slug="/film/glass-onion-a-knives-out-mystery/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/glass-onion-a-knives-out-mystery/image-150/" data-show-menu="true" data-target-link="/film/glass-onion-a-knives-out-mystery/" data-target-link-target=""> <img alt="Glass Onion: A Knives Out Mystery" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-8">★★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-598882 linked-film-poster" data-cache-busting-key="03be9e08" data-film-id="598882" data-film-slug="/film/the-banshees-of-inisherin/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/the-banshees-of-inisherin/image-150/" data-show-menu="true" data-target-link="/film/the-banshees-of-inisherin/" data-target-link-target=""> <img alt="The Banshees of Inisherin" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata -rated-and-liked"> <span class="rating -tiny -darker rated-10">★★★★★</span> <span class="like has-icon icon-liked icon-16"><span class="icon"></span></span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-748410 linked-film-poster" data-cache-busting-key="0cacc4e7" data-film-id="748410" data-film-slug="/film/stealing-raden-saleh/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/stealing-raden-saleh/image-150/" data-show-menu="true" data-target-link="/film/stealing-raden-saleh/" data-target-link-target=""> <img alt="Stealing Raden Saleh" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-9">★★★★½</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-915924 linked-film-poster" data-cache-busting-key="6cf8f54a" data-film-id="915924" data-film-slug="/film/all-or-nothing-arsenal/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/all-or-nothing-arsenal/image-150/" data-show-menu="true" data-target-link="/film/all-or-nothing-arsenal/" data-target-link-target=""> <img alt="All or Nothing: Arsenal" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-8">★★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-682547 linked-film-poster" data-cache-busting-key="8289ec9f" data-film-id="682547" data-film-slug="/film/nope/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/nope/image-150/" data-show-menu="true" data-target-link="/film/nope/" data-target-link-target=""> <img alt="Nope" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-8">★★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-813576 linked-film-poster" data-cache-busting-key="01e8d4e7" data-film-id="813576" data-film-slug="/film/missing-home/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/missing-home/image-150/" data-show-menu="true" data-target-link="/film/missing-home/" data-target-link-target=""> <img alt="Missing Home" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-9">★★★★½</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-542032 linked-film-poster" data-cache-busting-key="83f935ad" data-film-id="542032" data-film-slug="/film/elvis-2022/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/elvis-2022/image-150/" data-show-menu="true" data-target-link="/film/elvis-2022/" data-target-link-target=""> <img alt="Elvis" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-8">★★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-699298 linked-film-poster" data-cache-busting-key="09a6ba69" data-film-id="699298" data-film-slug="/film/men-2022/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/men-2022/image-150/" data-show-menu="true" data-target-link="/film/men-2022/" data-target-link-target=""> <img alt="Men" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-5">★★½</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-830325 linked-film-poster" data-cache-busting-key="43fbd41c" data-film-id="830325" data-film-slug="/film/srimulat-hil-yang-mustahal-babak-pertama/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/srimulat-hil-yang-mustahal-babak-pertama/image-150/" data-show-menu="true" data-target-link="/film/srimulat-hil-yang-mustahal-babak-pertama/" data-target-link-target=""> <img alt="Srimulat: Hil Yang Mustahal – Babak Pertama" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-8">★★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-385511 linked-film-poster" data-cache-busting-key="81a4fea9" data-film-id="385511" data-film-slug="/film/doctor-strange-in-the-multiverse-of-madness/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/doctor-strange-in-the-multiverse-of-madness/image-150/" data-show-menu="true" data-target-link="/film/doctor-strange-in-the-multiverse-of-madness/" data-target-link-target=""> <img alt="Doctor Strange in the Multiverse of Madness" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-8">★★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-600103 linked-film-poster" data-cache-busting-key="89d972d5" data-film-id="600103" data-film-slug="/film/sonic-the-hedgehog-2/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/sonic-the-hedgehog-2/image-150/" data-show-menu="true" data-target-link="/film/sonic-the-hedgehog-2/" data-target-link-target=""> <img alt="Sonic the Hedgehog 2" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata -rated-and-liked"> <span class="rating -tiny -darker rated-8">★★★★</span> <span class="like has-icon icon-liked icon-16"><span class="icon"></span></span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-474474 linked-film-poster" data-cache-busting-key="80fbb370" data-film-id="474474" data-film-slug="/film/everything-everywhere-all-at-once/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/everything-everywhere-all-at-once/image-150/" data-show-menu="true" data-target-link="/film/everything-everywhere-all-at-once/" data-target-link-target=""> <img alt="Everything Everywhere All at Once" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata -rated-and-liked"> <span class="rating -tiny -darker rated-9">★★★★½</span> <span class="like has-icon icon-liked icon-16"><span class="icon"></span></span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-348914 linked-film-poster" data-cache-busting-key="0438ab74" data-film-id="348914" data-film-slug="/film/the-batman/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/the-batman/image-150/" data-show-menu="true" data-target-link="/film/the-batman/" data-target-link-target=""> <img alt="The Batman" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata -rated-and-liked"> <span class="rating -tiny -darker rated-9">★★★★½</span> <span class="like has-icon icon-liked icon-16"><span class="icon"></span></span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-836165 linked-film-poster" data-cache-busting-key="837d366c" data-film-id="836165" data-film-slug="/film/neymar-the-perfect-chaos/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/neymar-the-perfect-chaos/image-150/" data-show-menu="true" data-target-link="/film/neymar-the-perfect-chaos/" data-target-link-target=""> <img alt="Neymar: The Perfect Chaos" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-8">★★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-560787 linked-film-poster" data-cache-busting-key="85a9e72a" data-film-id="560787" data-film-slug="/film/spider-man-no-way-home/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/spider-man-no-way-home/image-150/" data-show-menu="true" data-target-link="/film/spider-man-no-way-home/" data-target-link-target=""> <img alt="Spider-Man: No Way Home" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-7">★★★½</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-606030 linked-film-poster" data-cache-busting-key="858b3072" data-film-id="606030" data-film-slug="/film/nussa/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/nussa/image-150/" data-show-menu="true" data-target-link="/film/nussa/" data-target-link-target=""> <img alt="Nussa" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-7">★★★½</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-780166 linked-film-poster" data-cache-busting-key="05f76be8" data-film-id="780166" data-film-slug="/film/clickbait-2021/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/clickbait-2021/image-150/" data-show-menu="true" data-target-link="/film/clickbait-2021/" data-target-link-target=""> <img alt="Clickbait" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-7">★★★½</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-479814 linked-film-poster" data-cache-busting-key="0385d7f0" data-film-id="479814" data-film-slug="/film/free-guy/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/free-guy/image-150/" data-show-menu="true" data-target-link="/film/free-guy/" data-target-link-target=""> <img alt="Free Guy" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-8">★★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-369835 linked-film-poster" data-cache-busting-key="065e9e62" data-film-id="369835" data-film-slug="/film/the-suicide-squad/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/the-suicide-squad/image-150/" data-show-menu="true" data-target-link="/film/the-suicide-squad/" data-target-link-target=""> <img alt="The Suicide Squad" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata -rated-and-liked"> <span class="rating -tiny -darker rated-8">★★★★</span> <span class="like has-icon icon-liked icon-16"><span class="icon"></span></span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-683620 linked-film-poster" data-cache-busting-key="88c58cd4" data-film-id="683620" data-film-slug="/film/red-rocket-2021/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/red-rocket-2021/image-150/" data-show-menu="true" data-target-link="/film/red-rocket-2021/" data-target-link-target=""> <img alt="Red Rocket" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-9">★★★★½</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-266676 linked-film-poster" data-cache-busting-key="8797a490" data-film-id="266676" data-film-slug="/film/cruella/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/cruella/image-150/" data-show-menu="true" data-target-link="/film/cruella/" data-target-link-target=""> <img alt="Cruella" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-6">★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-563643 linked-film-poster" data-cache-busting-key="86927384" data-film-id="563643" data-film-slug="/film/wrath-of-man/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/wrath-of-man/image-150/" data-show-menu="true" data-target-link="/film/wrath-of-man/" data-target-link-target=""> <img alt="Wrath of Man" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-7">★★★½</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-392290 linked-film-poster" data-cache-busting-key="846d7195" data-film-id="392290" data-film-slug="/film/mortal-kombat-2021/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/mortal-kombat-2021/image-150/" data-show-menu="true" data-target-link="/film/mortal-kombat-2021/" data-target-link-target=""> <img alt="Mortal Kombat" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-7">★★★½</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-542555 linked-film-poster" data-cache-busting-key="0d239160" data-film-id="542555" data-film-slug="/film/nobody-2021/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/nobody-2021/image-150/" data-show-menu="true" data-target-link="/film/nobody-2021/" data-target-link-target=""> <img alt="Nobody" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-8">★★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-597511 linked-film-poster" data-cache-busting-key="8fb31aa7" data-film-id="597511" data-film-slug="/film/the-heartbreak-club/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/the-heartbreak-club/image-150/" data-show-menu="true" data-target-link="/film/the-heartbreak-club/" data-target-link-target=""> <img alt="The Heartbreak Club" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-6">★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-662656 linked-film-poster" data-cache-busting-key="85e44a4c" data-film-id="662656" data-film-slug="/film/borat-subsequent-moviefilm/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/borat-subsequent-moviefilm/image-150/" data-show-menu="true" data-target-link="/film/borat-subsequent-moviefilm/" data-target-link-target=""> <img alt="Borat Subsequent Moviefilm" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-8">★★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-662819 linked-film-poster" data-cache-busting-key="829c8742" data-film-id="662819" data-film-slug="/film/blackpink-light-up-the-sky/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/blackpink-light-up-the-sky/image-150/" data-show-menu="true" data-target-link="/film/blackpink-light-up-the-sky/" data-target-link-target=""> <img alt="BLACKPINK: Light Up the Sky" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-7">★★★½</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-559941 linked-film-poster" data-cache-busting-key="8be5ad08" data-film-id="559941" data-film-slug="/film/the-east-2020/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/the-east-2020/image-150/" data-show-menu="true" data-target-link="/film/the-east-2020/" data-target-link-target=""> <img alt="The East" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-7">★★★½</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-427852 linked-film-poster" data-cache-busting-key="8e71e2b6" data-film-id="427852" data-film-slug="/film/enola-holmes/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/enola-holmes/image-150/" data-show-menu="true" data-target-link="/film/enola-holmes/" data-target-link-target=""> <img alt="Enola Holmes" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata -rated-and-liked"> <span class="rating -tiny -darker rated-8">★★★★</span> <span class="like has-icon icon-liked icon-16"><span class="icon"></span></span> </p>
# </li>
# <li class="poster-container">
# ...
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-532074 linked-film-poster" data-cache-busting-key="86334bd9" data-film-id="532074" data-film-slug="/film/chase-2019/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/chase-2019/image-150/" data-show-menu="true" data-target-link="/film/chase-2019/" data-target-link-target=""> <img alt="Chase" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-7">★★★½</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-390039 linked-film-poster" data-cache-busting-key="87991b44" data-film-id="390039" data-film-slug="/film/john-wick-chapter-3-parabellum/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/john-wick-chapter-3-parabellum/image-150/" data-show-menu="true" data-target-link="/film/john-wick-chapter-3-parabellum/" data-target-link-target=""> <img alt="John Wick: Chapter 3 - Parabellum" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-7">★★★½</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-430641 linked-film-poster" data-cache-busting-key="827f17bd" data-film-id="430641" data-film-slug="/film/the-highwaymen/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/the-highwaymen/image-150/" data-show-menu="true" data-target-link="/film/the-highwaymen/" data-target-link-target=""> <img alt="The Highwaymen" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-8">★★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-442715 linked-film-poster" data-cache-busting-key="0708e797" data-film-id="442715" data-film-slug="/film/stuber/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/stuber/image-150/" data-show-menu="true" data-target-link="/film/stuber/" data-target-link-target=""> <img alt="Stuber" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-7">★★★½</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-390520 linked-film-poster" data-cache-busting-key="8e09fc83" data-film-id="390520" data-film-slug="/film/us-2019/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/us-2019/image-150/" data-show-menu="true" data-target-link="/film/us-2019/" data-target-link-target=""> <img alt="Us" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-8">★★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-378081 linked-film-poster" data-cache-busting-key="0fa711ca" data-film-id="378081" data-film-slug="/film/fighting-with-my-family/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/fighting-with-my-family/image-150/" data-show-menu="true" data-target-link="/film/fighting-with-my-family/" data-target-link-target=""> <img alt="Fighting with My Family" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-6">★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-414763 linked-film-poster" data-cache-busting-key="0ded50d2" data-film-id="414763" data-film-slug="/film/polar-2019/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/polar-2019/image-150/" data-show-menu="true" data-target-link="/film/polar-2019/" data-target-link-target=""> <img alt="Polar" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-6">★★★</span> </p>
# </li>
# <li class="poster-container">
# <div class="really-lazy-load poster film-poster film-poster-434068 linked-film-poster" data-cache-busting-key="850edcaa" data-film-id="434068" data-film-slug="/film/the-mule-2018/" data-image-height="105" data-image-width="70" data-linked="linked" data-poster-url="/film/the-mule-2018/image-150/" data-show-menu="true" data-target-link="/film/the-mule-2018/" data-target-link-target=""> <img alt="The Mule" class="image" height="105" src="https://s.ltrbxd.com/static/img/empty-poster-70.8112b435.png" width="70"/> <span class="frame"><span class="frame-title"></span></span> </div> <p class="poster-viewingdata"> <span class="rating -tiny -darker rated-6">★★★</span> </p>
# </li>
# </ul>
# <div class="pagination"> <div class="paginate-nextprev paginate-disabled"><span class="previous">Newer</span></div> <div class="paginate-nextprev"><a class="next" href="/cacingpincang/films/page/2/">Older</a></div> <div class="paginate-pages"> <ul> <li class="paginate-page paginate-current"><span>1</span></li> <li class="paginate-page"><a href="/cacingpincang/films/page/2/">2</a></li> <li class="paginate-page"><a href="/cacingpincang/films/page/3/">3</a></li> <li class="paginate-page"><a href="/cacingpincang/films/page/4/">4</a></li> </ul> </div> </div>
# <div class="clear"></div>
# </section>
# <div class="clear"></div>
# </div>
# </div>
# </div>
# <footer class="page-footer js-page-footer js-hide-in-app" id="page-footer">
# <div class="content-wrap">
# <nav class="footer-nav js-footer-nav">
# <ul>
# <li><a href="/about/">About</a></li>
# <li><a href="/journal/">News</a></li>
# <li class="js-hide-in-app"><a href="/pro/">Pro</a></li>
# <li><a href="/apps/">Apps</a></li>
# <li><a href="https://apple.co/3TfzHVG" rel="noopener noreferrer" target="_blank">Podcast</a></li>
# <li><a href="/year-in-review/">Year in Review</a></li>
# <li><a href="/gift-guide/">Gift Guide</a></li>
# <li><a href="/welcome/">Help</a></li>
# <li><a href="/legal/terms-of-use/">Terms</a></li>
# <li><a href="/api-beta/">API</a></li>
# <li><a href="/contact/">Contact</a></li>
# </ul>
# </nav>
# <div class="socials">
# <nav class="social-service-list -inline">
# <div class="listitem -icononly">
# <a class="trigger tooltip" href="https://twitter.com/letterboxd" rel="noopener noreferrer" target="_blank" title="Letterboxd on Twitter">
# <svg aria-hidden="true" class="glyph" height="16" role="presentation" width="20" xmlns="http://www.w3.org/2000/svg"><path d="M17.96 4.51V4c.8-.56 1.49-1.28 2.04-2.1-.74.33-1.53.54-2.36.65.85-.5 1.5-1.3 1.8-2.24-.78.46-1.66.8-2.6.98a4.13 4.13 0 0 0-7.1 2.76c0 .31.04.62.1.92A11.72 11.72 0 0 1 1.38.74a3.99 3.99 0 0 0 1.28 5.4A4.2 4.2 0 0 1 .8 5.62v.06c0 1.95 1.42 3.59 3.29 3.96a4.06 4.06 0 0 1-1.85.07 4.1 4.1 0 0 0 3.83 2.8A8.32 8.32 0 0 1 0 14.2C1.8 15.33 3.97 16 6.28 16A11.5 11.5 0 0 0 17.96 4.51Z"></path></svg>
# <span class="label">Twitter</span>
# </a>
# </div>
# <div class="listitem -icononly">
# <a class="trigger tooltip" href="https://www.facebook.com/letterboxd" rel="noopener noreferrer" target="_blank" title="Letterboxd on Facebook">
# <svg aria-hidden="true" class="glyph" height="19" role="presentation" width="19" xmlns="http://www.w3.org/2000/svg"><path d="M9.5 0a9.5 9.5 0 0 0-1.48 18.89V12H5.6V9.25h2.42V7.41c0-2.38 1.41-3.7 3.58-3.7 1.04 0 2.13.19 2.13.19v2.33h-1.2c-1.18 0-1.54.74-1.54 1.49v1.53h2.63L13.2 12h-2.21v6.89A9.5 9.5 0 0 0 9.5 0Z"></path></svg>
# <span class="label">Facebook</span>
# </a>
# </div>
# <div class="listitem -icononly">
# <a class="trigger tooltip" href="https://www.instagram.com/letterboxd" rel="noopener noreferrer" target="_blank" title="Letterboxd on Instagram">
# <svg aria-hidden="true" class="glyph" height="20" role="presentation" width="20" xmlns="http://www.w3.org/2000/svg"><path d="M14.12.06c1.07.05 1.8.22 2.43.46.66.26 1.21.6 1.77 1.16.56.55.9 1.11 1.15 1.77.25.63.42 1.36.47 2.43.04.94.06 1.32.06 3.3v1.37c0 1.54 0 2.19-.03 2.77v.22l-.03.58a7.34 7.34 0 0 1-.47 2.43 4.9 4.9 0 0 1-1.15 1.77 4.9 4.9 0 0 1-1.77 1.16c-.64.24-1.36.41-2.43.46l-.61.03h-.23c-.5.02-1.06.03-2.21.03H9.2c-2 0-2.37-.02-3.32-.06a7.34 7.34 0 0 1-2.43-.46 4.9 4.9 0 0 1-1.77-1.16 4.9 4.9 0 0 1-1.16-1.77 7.34 7.34 0 0 1-.46-2.43l-.03-.61v-.2A60.9 60.9 0 0 1 0 11.5V8.75C0 7.7.01 7.17.03 6.7v-.2l.03-.61C.1 4.8.28 4.08.52 3.45a4.9 4.9 0 0 1 1.16-1.77A4.9 4.9 0 0 1 3.45.52 7.34 7.34 0 0 1 5.88.06l.61-.03h.2C7.12 0 7.6 0 8.5 0h2.74c1.62 0 2 .02 2.88.06ZM11.02 2H8.97c-1.7 0-2.05.02-2.92.06a5.4 5.4 0 0 0-1.82.33c-.45.18-.78.39-1.12.73-.34.34-.55.67-.73 1.12-.13.35-.3.86-.33 1.82C2.02 6.93 2 7.29 2 8.98v2.04c0 1.7.02 2.05.06 2.92.04.95.2 1.47.33 1.81.18.46.39.78.73 1.13.34.34.67.55 1.12.73.35.13.86.29 1.82.33.83.04 1.2.05 2.7.06h2.47c1.51 0 1.87-.02 2.71-.06a5.4 5.4 0 0 0 1.81-.33c.46-.18.78-.4 1.12-.73.35-.35.56-.67.73-1.13.14-.34.3-.86.34-1.8a49 49 0 0 0 .06-2.72V8.77a49 49 0 0 0-.06-2.71 5.4 5.4 0 0 0-.34-1.82 3.02 3.02 0 0 0-.73-1.12 3.02 3.02 0 0 0-1.12-.73 5.4 5.4 0 0 0-1.81-.33c-.88-.04-1.23-.06-2.93-.06ZM10 4.86a5.14 5.14 0 1 1 0 10.28 5.14 5.14 0 0 1 0-10.28ZM10 7a3 3 0 1 0 0 6 3 3 0 0 0 0-6Zm5.25-3.5a1.25 1.25 0 1 1 0 2.5 1.25 1.25 0 0 1 0-2.5Z"></path></svg>
# <span class="label">Instagram</span>
# </a>
# </div>
# <div class="listitem -icononly">
# <a class="trigger tooltip" href="https://www.youtube.com/letterboxdhq" rel="noopener noreferrer" target="_blank" title="Letterboxd on YouTube">
# <svg aria-hidden="true" class="glyph" height="16" role="presentation" width="23" xmlns="http://www.w3.org/2000/svg"><path d="M11.74 0c.61 0 2.33.02 4.11.08l.54.02c1.7.06 3.35.18 4.1.38a2.87 2.87 0 0 1 2.03 2.02c.45 1.67.48 5.04.48 5.46v.08c0 .42-.03 3.8-.48 5.46a2.87 2.87 0 0 1-2.03 2.02c-.75.2-2.4.32-4.1.38l-.54.02c-1.78.07-3.5.08-4.11.08H11.26c-.62 0-2.33-.01-4.11-.08l-.54-.02c-1.7-.06-3.36-.18-4.1-.38A2.87 2.87 0 0 1 .48 13.5C.04 11.9 0 8.68 0 8.1v-.2c0-.58.04-3.79.48-5.4A2.87 2.87 0 0 1 2.5.48c.74-.2 2.4-.32 4.1-.38l.54-.02C8.93.02 10.65 0 11.26 0ZM9 4.57v6.86L15 8 9 4.57Z"></path></svg>
# <span class="label">YouTube</span>
# </a>
# </div>
# <div class="listitem -icononly">
# <a class="trigger tooltip" href="https://www.tiktok.com/@letterboxd" rel="noopener noreferrer" target="_blank" title="Letterboxd on TikTok">
# <svg aria-hidden="true" class="glyph" height="18" role="presentation" width="17" xmlns="http://www.w3.org/2000/svg"><path d="M16.48 4.32a4.62 4.62 0 0 1-3.92-2.66A4.04 4.04 0 0 1 12.23 0H9.07v11.85c0 1.93-1.19 3.07-2.65 3.07a2.71 2.71 0 0 1-2.04-.9 2.57 2.57 0 0 1-.6-2.1 2.55 2.55 0 0 1 1.26-1.81 2.7 2.7 0 0 1 2.24-.21V6.77a5.92 5.92 0 0 0-4.08.86 5.7 5.7 0 0 0-2.15 2.55 5.53 5.53 0 0 0 1.26 6.16 5.86 5.86 0 0 0 6.33 1.23 5.78 5.78 0 0 0 2.6-2.08c.64-.94.98-2.03.98-3.15V5.96a7.74 7.74 0 0 0 4.25 1.25V4.32Z"></path></svg>
# <span class="label">TikTok</span>
# </a>
# </div>
# </nav>
# </div>
# <p class="copyright">
# 				© Letterboxd Limited. Made by <a class="mute" href="/crew/">fans</a> in Aotearoa New Zealand.
# 				<span class="nobr"><a class="mute" href="https://letterboxd.com/about/film-data/">Film data</a> from <a class="mute" href="https://www.themoviedb.org">TMDb</a>.
#
# 						<a class="mute mobile-site-switch" data-use-mobile-site="yes" href="#">Mobile site</a>.
#
# 	</span>
# <span class="recap" style="display:none"><br/>This site is protected by reCAPTCHA and the Google <a class="mute" href="https://policies.google.com/privacy" rel="noopener noreferrer" target="_blank">privacy policy</a> and <a class="mute" href="https://policies.google.com/terms" rel="noopener noreferrer" target="_blank">terms of service</a> apply.</span>
# </p>
# </div>
# </footer>
# <div aria-hidden="true" aria-labelledby="remove-ads-modal-title" class="modal-neue fade" id="remove-ads-modal" tabindex="-1">
# <div class="modal-dialog -sm modal-dialog-centered">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title" id="remove-ads-modal-title">Upgrade to remove ads</h5>
# <button aria-label="Close" class="close" data-bs-dismiss="modal-neue" type="button">
# <svg class="glyph" height="16" width="16" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd" stroke="#000" stroke-linecap="round" stroke-width="2"><path d="m1 1 14 14M1 15 15 1"></path></g></svg>
# </button>
# </div>
# <div class="modal-body">
# <div class="body-text -hero">
# <p>Letterboxd is an independent service created by a small team, and we rely mostly on the support of our members to maintain our site and apps. Please consider upgrading to a <a href="/pro/">Pro account</a>—for less than a couple bucks a month, you’ll get cool additional features like all-time and annual stats pages (<a href="https://letterboxd.com/jack/stats/">example</a>), the ability to select (and filter by) your favorite streaming services, and no ads!</p>
# </div>
# </div>
# <div class="modal-footer">
# <a class="button -action button-action" href="/pro/">Learn more about Pro</a>
# </div>
# </div>
# </div>
# </div>
# <form action="" aria-hidden="true" aria-labelledby="poster-picker-modal-title" class="modal-neue fade poster-picker-modal" data-bs-backdrop="static" id="poster-picker-modal" method="post" novalidate="novalidate" role="dialog" tabindex="-1">
# <div class="modal-dialog -lg modal-dialog-centered modal-dialog-scrollable">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title" id="poster-picker-modal-title">Select your preferred poster</h5>
# <button aria-label="Close" class="close" data-bs-dismiss="modal-neue" type="button">
# <svg class="glyph" height="16" width="16" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd" stroke="#000" stroke-linecap="round" stroke-width="2"><path d="m1 1 14 14M1 15 15 1"></path></g></svg>
# </button>
# </div>
# <div class="modal-body">
# <div data-js-target="poster-picker" data-poster-picker-options='{"id": "1950f699-d0c6-43e3-a280-732fe1b1d294"}' id="poster-picker-1950f699-d0c6-43e3-a280-732fe1b1d294"></div>
# </div>
# <div class="modal-footer">
# <div class="poster-picker-note">
# <div class="body-text -small">
# <p>Posters are sourced from <a href="https://www.themoviedb.org" target="_blank">TMDb</a> and <a href="https://posteritati.com" target="_blank">Posteritati</a>, and appear for you and visitors to your profile and content, depending on settings. <a href="https://letterboxd.com/journal/posterity-custom-posters/" target="_blank">Learn more.</a></p>
# </div>
# </div>
# <div class="poster-picker-controls" data-poster-picker-controls-for="1950f699-d0c6-43e3-a280-732fe1b1d294">
# <div class="modal-action-group -center">
# <button class="button -destructive" data-js-trigger="reset" disabled="" type="button"><span class="label">Reset poster</span></button>
# <button class="button -action" data-js-trigger="submit" disabled="" type="submit"><span class="label">Save<span class="mob-hide"> changes</span></span></button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# <script defer="" src="https://s.ltrbxd.com/static/js/partner-publishers.min.6fc86c8d.js"></script>
# </body>
# </html>

# %% [markdown]
# ### Checkpoint 1
# - the movie list is inside unordered list (ul) tag with class name of "poster-list -p70 -grid film-list clear", so we will find that tag to get the list of movies
# - the information we could take is the movie's rating, title, liked or not, and link
# - the rating format is in stars, so we need a function that transforms it into number
# - we also need to deal with pagination

# %%
def transform_ratings(some_str):
    """
    transforms raw star rating into float value
    :param: some_str: actual star rating
    :rtype: returns the float representation of the given star(s)
    """
    stars = {
        "★": 1,
        "★★": 2,
        "★★★": 3,
        "★★★★": 4,
        "★★★★★": 5,
        "½": 0.5,
        "★½": 1.5,
        "★★½": 2.5,
        "★★★½": 3.5,
        "★★★★½": 4.5
    }
    try:
        return stars[some_str]
    except:
        return -1

# find the unordered list
ul = soup.find("ul", {"class": "poster-list"})

# find the <li> inside <ul>
movies = ul.find_all("li")
# we will try to iterate through the movies and then print the title and rating
for movie in movies:
  print(movie.find('img')['alt'])
  print(movie.find('p', {"class": "poster-viewingdata"}).get_text().strip())
  print(transform_ratings(movie.find('p', {"class": "poster-viewingdata"}).get_text().strip()))
  print("Liked: " + str(movie.find('span', {'class': 'like'})!=None))
# Out:
# A Man Called Otto
# ★★★★
# 4
# Liked: False
# Puss in Boots: The Last Wish
# ★★★★★
# 5
# Liked: True
# The Menu
# ★★★★
# 4
# Liked: False
# Glass Onion: A Knives Out Mystery
# ★★★★
# 4
# Liked: False
# The Banshees of Inisherin
# ★★★★★
# 5
# Liked: True
# Stealing Raden Saleh
# ★★★★½
# 4.5
# Liked: False
# All or Nothing: Arsenal
# ★★★★
# 4
# Liked: False
# Nope
# ★★★★
# 4
# Liked: False
# Missing Home
# ★★★★½
# 4.5
# Liked: False
# Elvis
# ★★★★
# 4
# Liked: False
# Men
# ★★½
# 2.5
# Liked: False
# Srimulat: Hil Yang Mustahal – Babak Pertama
# ★★★★
# 4
# Liked: False
# Doctor Strange in the Multiverse of Madness
# ★★★★
# 4
# Liked: False
# Sonic the Hedgehog 2
# ★★★★
# 4
# Liked: True
# Everything Everywhere All at Once
# ★★★★½
# 4.5
# Liked: True
# The Batman
# ★★★★½
# 4.5
# Liked: True
# Neymar: The Perfect Chaos
# ★★★★
# 4
# Liked: False
# Spider-Man: No Way Home
# ★★★½
# 3.5
# Liked: False
# Nussa
# ★★★½
# 3.5
# Liked: False
# Clickbait
# ★★★½
# 3.5
# Liked: False
# Free Guy
# ★★★★
# 4
# Liked: False
# The Suicide Squad
# ★★★★
# 4
# Liked: True
# Red Rocket
# ★★★★½
# 4.5
# Liked: False
# Cruella
# ★★★
# 3
# Liked: False
# Wrath of Man
# ★★★½
# 3.5
# Liked: False
# Mortal Kombat
# ★★★½
# 3.5
# Liked: False
# Nobody
# ★★★★
# 4
# Liked: False
# The Heartbreak Club
# ★★★
# 3
# Liked: False
# Borat Subsequent Moviefilm
# ★★★★
# 4
# Liked: False
# BLACKPINK: Light Up the Sky
# ★★★½
# 3.5
# Liked: False
# The East
# ★★★½
# 3.5
# Liked: False
# Enola Holmes
# ★★★★
# 4
# Liked: True
# I Care a Lot
# ★★★★
# 4
# Liked: True
# The Devil All the Time
# ★★★★½
# 4.5
# Liked: True
# All or Nothing: Tottenham Hotspur
# ★★★★
# 4
# Liked: False
# I'm Thinking of Ending Things
# ★★★★
# 4
# Liked: True
# The SpongeBob Movie: Sponge on the Run
# ★★★
# 3
# Liked: False
# Backstreet Rookie
# ★★★½
# 3.5
# Liked: False
# Scoob!
# ★★½
# 2.5
# Liked: False
# The Last Dance
# ★★★½
# 3.5
# Liked: False
# The Hunt
# ★★★½
# 3.5
# Liked: True
# Spenser Confidential
# ★★★
# 3
# Liked: False
# The Social Dilemma
# ★★★★
# 4
# Liked: True
# Sonic the Hedgehog
# ★★★★
# 4
# Liked: True
# Promising Young Woman
# ★★★★½
# 4.5
# Liked: True
# Bad Boys for Life
# ★★★
# 3
# Liked: False
# One Day We'll Talk About Today
# ★★★★
# 4
# Liked: True
# Imperfect
# ★★★★½
# 4.5
# Liked: False
# 1917
# ★★★★½
# 4.5
# Liked: False
# The Gentlemen
# ★★★½
# 3.5
# Liked: False
# The Queen of Black Magic
# ★★★½
# 3.5
# Liked: False
# Impetigore
# ★★★
# 3
# Liked: False
# El Camino: A Breaking Bad Movie
# ★★★
# 3
# Liked: False
# Guns Akimbo
# ★★★½
# 3.5
# Liked: True
# Jojo Rabbit
# ★★★★★
# 5
# Liked: True
# Knives Out
# ★★★★
# 4
# Liked: False
# Joker
# ★★★★
# 4
# Liked: False
# It Chapter Two
# ★★★½
# 3.5
# Liked: False
# The Lion King
# ★★★
# 3
# Liked: False
# Midsommar
# ★★★½
# 3.5
# Liked: False
# Toy Story 4
# ★★★★
# 4
# Liked: False
# Deadwood: The Movie
# ★★★½
# 3.5
# Liked: False
# Parasite
# ★★★★½
# 4.5
# Liked: False
# Once Upon a Time… in Hollywood
# ★★★★½
# 4.5
# Liked: False
# Chase
# ★★★½
# 3.5
# Liked: False
# John Wick: Chapter 3 - Parabellum
# ★★★½
# 3.5
# Liked: False
# The Highwaymen
# ★★★★
# 4
# Liked: False
# Stuber
# ★★★½
# 3.5
# Liked: False
# Us
# ★★★★
# 4
# Liked: False
# Fighting with My Family
# ★★★
# 3
# Liked: False
# Polar
# ★★★
# 3
# Liked: False
# The Mule
# ★★★
# 3
# Liked: False

# %%
# dealing with pagination
li_pagination = soup.findAll("li", {"class": "paginate-page"})
li_pagination
# Out:
# [<li class="paginate-page paginate-current"><span>1</span></li>,
#  <li class="paginate-page"><a href="/cacingpincang/films/page/2/">2</a></li>,
#  <li class="paginate-page"><a href="/cacingpincang/films/page/3/">3</a></li>,
#  <li class="paginate-page"><a href="/cacingpincang/films/page/4/">4</a></li>]

# %%
if len(li_pagination) == 0:
  # this is when there's only one page
  ul = soup.find("ul", {"class": "poster-list"})
  if (ul != None):
    movies = ul.find_all("li")
else:
  # this is when there's more than one page
  for i in range(len(li_pagination)):
    url = DOMAIN + "/" + username + "/films/page/" + str(i+1)
    url_page = requests.get(url)
    soup = BeautifulSoup(url_page.content, 'html.parser')
    ul = soup.find("ul", {"class": "poster-list"})
    if (ul != None):
      movies = ul.find_all("li")
      print("the first movie of page {} is {}".format(i+1, movies[0].find('img')['alt']))
# Out:
# the first movie of page 1 is A Man Called Otto
# the first movie of page 2 is Take the Ball, Pass the Ball
# the first movie of page 3 is 3 Idiots
# the first movie of page 4 is Reservoir Dogs

# %%
# we will store the data to a pandas dataframe
# so the final function will be like this

def scrape_films(username):
    movies_dict = {}
    movies_dict['id'] = []
    movies_dict['title'] = []
    movies_dict['rating'] = []
    movies_dict['liked'] = []
    movies_dict['link'] = []
    url = DOMAIN + "/" + username + "/films/"
    url_page = requests.get(url)
    soup = BeautifulSoup(url_page.content, 'html.parser')
    
    # check number of pages
    li_pagination = soup.findAll("li", {"class": "paginate-page"})
    if len(li_pagination) == 0:
        ul = soup.find("ul", {"class": "poster-list"})
        if (ul != None):
            movies = ul.find_all("li")
            for movie in movies:
                movies_dict['id'].append(movie.find('div')['data-film-id'])
                movies_dict['title'].append(movie.find('img')['alt'])
                movies_dict['rating'].append(transform_ratings(movie.find('p', {"class": "poster-viewingdata"}).get_text().strip()))
                movies_dict['liked'].append(movie.find('span', {'class': 'like'})!=None)
                movies_dict['link'].append(movie.find('div')['data-target-link'])
    else:
        for i in range(len(li_pagination)):
            url = DOMAIN + "/" + username + "/films/page/" + str(i+1)
            url_page = requests.get(url)
            soup = BeautifulSoup(url_page.content, 'html.parser')
            ul = soup.find("ul", {"class": "poster-list"})
            if (ul != None):
                movies = ul.find_all("li")
                for movie in movies:
                    movies_dict['id'].append(movie.find('div')['data-film-id'])
                    movies_dict['title'].append(movie.find('img')['alt'])
                    movies_dict['rating'].append(transform_ratings(movie.find('p', {"class": "poster-viewingdata"}).get_text().strip()))
                    movies_dict['liked'].append(movie.find('span', {'class': 'like'})!=None)
                    movies_dict['link'].append(movie.find('div')['data-target-link'])
    
    df_film = pd.DataFrame(movies_dict)    
    return df_film

# %%
# let's try it
my_film = scrape_films("cacingpincang")

# %%
my_film.head()
# Out:
#        id                              title  rating  liked  \
# 0  842221                  A Man Called Otto     4.0  False
# 1  242285       Puss in Boots: The Last Wish     5.0   True
# 2  521323                           The Menu     4.0  False
# 3  586723  Glass Onion: A Knives Out Mystery     4.0  False
# 4  598882          The Banshees of Inisherin     5.0   True
#
#                                       link
# 0                 /film/a-man-called-otto/
# 1       /film/puss-in-boots-the-last-wish/
# 2                     /film/the-menu-2022/
# 3  /film/glass-onion-a-knives-out-mystery/
# 4         /film/the-banshees-of-inisherin/

# %% [markdown]
# ## Checkpoint 2
# - It worked!!

# %% [markdown]
# # Creating Other Functions
# - Now we will scrape the friends list with similar approach, but for efficiency I will directly give the final function
# - In this case, I will give 4 different interpretation of 'friends', (1) following, (2) followers, (3) union of following and followers, and (4) mutual/intersection of following and followers

# %%
def list_friends(username, ftype='following'):
    friends_list = []
    if ((ftype == 'following') | (ftype == 'followers')):
        url = DOMAIN + "/" + username + "/{0}/".format(ftype)
        while True:
            url_page = requests.get(url)
            soup = BeautifulSoup(url_page.content, 'html.parser')
            friends = soup.findAll('div', {'class':'person-summary'})

            for friend in friends:
                username_b = friend.find('a', {'class':'avatar'})['href'].replace('/','')
                friends_list.append(username_b)

            # check if there's next page
            if soup.find('a', {'class':'next'}) is None:
                break
            else:
                url = DOMAIN + soup.find('a', {'class':'next'})['href']
    elif (ftype == 'both'):
        url = DOMAIN + "/" + username + "/following/"
        while True:
            url_page = requests.get(url)
            soup = BeautifulSoup(url_page.content, 'html.parser')
            friends = soup.findAll('div', {'class':'person-summary'})

            for friend in friends:
                username_b = friend.find('a', {'class':'avatar'})['href'].replace('/','')
                friends_list.append(username_b)

            # check if there's next page
            if soup.find('a', {'class':'next'}) is None:
                break
            else:
                url = DOMAIN + soup.find('a', {'class':'next'})['href']
        url = DOMAIN + "/" + username + "/followers/"
        while True:
            url_page = requests.get(url)
            soup = BeautifulSoup(url_page.content, 'html.parser')
            friends = soup.findAll('div', {'class':'person-summary'})

            for friend in friends:
                username_b = friend.find('a', {'class':'avatar'})['href'].replace('/','')
                friends_list.append(username_b)

            # check if there's next page
            if soup.find('a', {'class':'next'}) is None:
                break
            else:
                url = DOMAIN + soup.find('a', {'class':'next'})['href']
        friends_list = list(dict.fromkeys(friends_list))
    elif (ftype == 'mutual'):
        following_list = []
        url = DOMAIN + "/" + username + "/following/"
        while True:
            url_page = requests.get(url)
            soup = BeautifulSoup(url_page.content, 'html.parser')
            friends = soup.findAll('div', {'class':'person-summary'})

            for friend in friends:
                username_b = friend.find('a', {'class':'avatar'})['href'].replace('/','')
                following_list.append(username_b)

            # check if there's next page
            if soup.find('a', {'class':'next'}) is None:
                break
            else:
                url = DOMAIN + soup.find('a', {'class':'next'})['href']
        followers_list = []
        url = DOMAIN + "/" + username + "/followers/"
        while True:
            url_page = requests.get(url)
            soup = BeautifulSoup(url_page.content, 'html.parser')
            friends = soup.findAll('div', {'class':'person-summary'})

            for friend in friends:
                username_b = friend.find('a', {'class':'avatar'})['href'].replace('/','')
                followers_list.append(username_b)

            # check if there's next page
            if soup.find('a', {'class':'next'}) is None:
                break
            else:
                url = DOMAIN + soup.find('a', {'class':'next'})['href']
        for following in following_list:
            if following in followers_list:
                friends_list.append(following)
    return friends_list

# %%
my_friends = list_friends('cacingpincang', 'mutual')

# %%
my_friends[:10]
# Out:
# ['jigsaw123',
#  'ashleewilliams',
#  'sefitofransgiox',
#  'alamledp',
#  'imajinasi',
#  'vonnysimarmata',
#  'ajinur',
#  'mukhlis',
#  'rez4',
#  'perryshadow']

# %% [markdown]
# ## Checkpoint 3
# - Now that we could get the username of our friends, we will use the previous function to get our friends' movies
# - We will also compare our friends' movies to ours so we need a function that defines similarity score
# - Lastly, we need a function to do comparison and summarize it in a table

# %% [markdown]
# ## My Simple Similarity Scoring System (the index_score column)
# - If you both like/don't like the movie and give the same ratings, the score is perfect (in this case: 2) it means you have the same exact opinion on that movie
# - If you both like the movie and give different ratings, the score is 2 (you both like it) minus the rating points difference divided by 5 (the range of the rating)
# - If you both don't like the movie and give different ratings, the score is 1 minus the rating points difference divided by 5 (the range of the rating)
#
# And the final score is similarity score multiplied by number of movies both have rated
# ### why multiply it with number of movies?
# my assumption is if I have very similar rating and liking behavior with my friend, but we watch different movies then we're not really close because we have different references

# %%
def score_index(rating_x, liked_x, rating_y, liked_y):
    score = 0.0
    if ((rating_x == rating_y) & (liked_x == liked_y)):
        score = 2.0
    # both like but different ratings
    elif ((liked_x == True) & (liked_x == liked_y)):
        score = 2.0-(abs(rating_x-rating_y)/5)
    else:
        score = 1.0-(abs(rating_x-rating_y)/5)
    return score


def compare_ratings_friends(username_a, df_a, username_b, df_b):
    
    # movies they both liked
    df_liked = pd.merge(df_a[['id', 'title', 'link', 'liked']], df_b[['id', 'liked']])
    df_liked = df_liked[df_liked['liked']==True].reset_index(drop=True)
    
    # movies they gave same rate
    df_same = pd.merge(df_a[['id', 'title', 'rating']], df_b[['id', 'rating']])
    
    # movies they gave different rate
    df_different = pd.merge(df_a[['id', 'title', 'rating']], df_b[['id', 'rating']], how='inner', on='id')
    df_different = df_different[df_different['rating_x']!=df_different['rating_y']].reset_index(drop=True)
    df_different['difference'] = df_different['rating_x']-df_different['rating_y']
    df_different['difference_abs'] = abs(df_different['rating_x']-df_different['rating_y'])
    df_different = df_different.rename(columns={'rating_x': 'rating_{0}'.format(username_a), 'rating_y': 'rating_{0}'.format(username_b)})
    
    # calculate index
    df_merge = pd.merge(df_a, df_b, on = ['id', 'title'])
    if len(df_merge) > 0:
        df_merge['score'] = df_merge.apply(lambda row: score_index(row['rating_x'], row['liked_x'],
                                                                   row['rating_y'], row['liked_y']),
                                           axis = 1)
        index = df_merge['score'].sum()/(2*len(df_merge))
    else:
        index = 0
    return df_liked, df_same, df_different, index

def scrape_friends(username, friends_list, limit=20):
    df_a = scrape_films(username)
    df_a = df_a[df_a['rating']!=-1].reset_index(drop=True)
    
    friends_dict = {}
    friends_dict['username'] = []
    friends_dict['index_score'] = []
    friends_dict['no_of_movies'] = []
    
    friends_data = {}
    for username_b in friends_list:
        print('scraping for '+username_b)
        df_b = scrape_films(username_b)
        df_b = df_b[df_b['rating']!=-1].reset_index(drop=True)
        no_of_movies = len(pd.merge(df_a[['id']], df_b[['id']]))
        # limit is the minimum number of movies you and your friend both rated
        # if number of movies you both have rated is less than the limit, then we won't calculate similarity
        if no_of_movies >= limit:
            friends_dict['username'].append(username_b)
            print('comparing for '+username_b)
            df_liked, df_same, df_different, index = compare_ratings_friends(username, df_a, username_b, df_b)
            friends_dict['index_score'].append(index)
            friends_dict['no_of_movies'].append(no_of_movies)
            friends_data[username_b] = {}
            friends_data[username_b]['df_b'] = df_b
            friends_data[username_b]['df_liked'] = df_liked
            friends_data[username_b]['df_same'] = df_same
            friends_data[username_b]['df_different'] = df_different

    df_friends = pd.DataFrame(friends_dict)
    # the final score of friends is similarity*number of movies you both have watched
    # why multiply it with number of movies?
    # my assumption is if I have very similar rating and liking behavior with my friend,
    # but we watch different movies then we're not really close because we have different references
    df_friends['total_index'] = df_friends['index_score']*df_friends['no_of_movies']
    return df_friends, friends_data, df_a

# %%
df_friends, friends_data, df_a = scrape_friends('cacingpincang', my_friends)
# Out:
# scraping for jigsaw123
# scraping for ashleewilliams
# scraping for sefitofransgiox
# scraping for alamledp
# comparing for alamledp
# scraping for imajinasi
# scraping for vonnysimarmata
# comparing for vonnysimarmata
# scraping for ajinur
# comparing for ajinur
# scraping for mukhlis
# comparing for mukhlis
# scraping for rez4
# scraping for perryshadow
# comparing for perryshadow
# scraping for vitaminc1
# comparing for vitaminc1
# scraping for wetuburubur
# scraping for omarlae2106
# comparing for omarlae2106
# scraping for brendonyu668
# comparing for brendonyu668
# scraping for bluewhale307
# scraping for ccj6529
# comparing for ccj6529
# scraping for katekidz
# comparing for katekidz
# scraping for jenniferrx
# comparing for jenniferrx
# scraping for inanamaa
# comparing for inanamaa
# scraping for asddljhgfh
# comparing for asddljhgfh
# scraping for outkastatlast
# scraping for christine2597
# comparing for christine2597
# scraping for jordlyphe
# comparing for jordlyphe
# scraping for resulonrsl
# comparing for resulonrsl
# scraping for txmnxwton
# comparing for txmnxwton
# scraping for laythtbaileh
# comparing for laythtbaileh
# scraping for ikiefriandi
# comparing for ikiefriandi
# scraping for bardjan
# comparing for bardjan
# scraping for theorollason
# comparing for theorollason
# scraping for zandar
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/merge.py:1204: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(
# comparing for zandar
# scraping for hjc2244
# comparing for hjc2244
# scraping for skipperjens
# comparing for skipperjens
# scraping for matthewzeitoun
# scraping for kikyrahmannisa
# comparing for kikyrahmannisa
# scraping for djdoublem3
# comparing for djdoublem3
# scraping for rom0618
# comparing for rom0618

# %%
# let's see my top 10 friends
df_friends.sort_values('total_index', ascending=False).head(10)
# Out:
#          username  index_score  no_of_movies  total_index
# 7    brendonyu668     0.641509            53        34.00
# 5       vitaminc1     0.596364            55        32.80
# 9        katekidz     0.573585            53        30.40
# 26        rom0618     0.571277            47        26.85
# 22        hjc2244     0.489815            54        26.45
# 17   laythtbaileh     0.625610            41        25.65
# 11       inanamaa     0.558889            45        25.15
# 0        alamledp     0.610256            39        23.80
# 3         mukhlis     0.547500            40        21.90
# 13  christine2597     0.487500            44        21.45

# %% [markdown]
# ## Checkpoint 4
# - Now that I know **brendonyu668** is my closest friend, I will try to look more into his highly rated movies hoping that I will probably like those movies too because we have similar taste

# %%
# movies that I and brendonyu668 liked
friends_data['brendonyu668']['df_liked']
# Out:
#         id                                      title  \
# 0   598882                  The Banshees of Inisherin
# 1   474474          Everything Everywhere All at Once
# 2   348914                                 The Batman
# 3   369835                          The Suicide Squad
# 4   510047                      Promising Young Woman
# 5   291610  Three Billboards Outside Ebbing, Missouri
# 6   353117                                    Get Out
# 7    52516                           Django Unchained
# 8    45409                             Shutter Island
# 9    40100                               The Hangover
# 10   41352                       Inglourious Basterds
# 11   43302                                         Up
#
#                                                link  liked
# 0                  /film/the-banshees-of-inisherin/   True
# 1          /film/everything-everywhere-all-at-once/   True
# 2                                 /film/the-batman/   True
# 3                          /film/the-suicide-squad/   True
# 4                      /film/promising-young-woman/   True
# 5   /film/three-billboards-outside-ebbing-missouri/   True
# 6                               /film/get-out-2017/   True
# 7                           /film/django-unchained/   True
# 8                             /film/shutter-island/   True
# 9                               /film/the-hangover/   True
# 10                      /film/inglourious-basterds/   True
# 11                                        /film/up/   True

# %%
# movies that brendonyu668 liked
friends_data['brendonyu668']['df_b'][friends_data['brendonyu668']['df_b']['liked'] == True].head(10)
# Out:
#         id                              title  rating  liked  \
# 1   484263     Guillermo del Toro's Pinocchio     4.5   True
# 2   521323                           The Menu     4.0   True
# 3   586723  Glass Onion: A Knives Out Mystery     4.0   True
# 4   598882          The Banshees of Inisherin     5.0   True
# 12  293465                  Top Gun: Maverick     5.0   True
# 14  565852                       The Northman     4.5   True
# 16  474474  Everything Everywhere All at Once     5.0   True
# 18  348914                         The Batman     4.5   True
# 21  441471                    West Side Story     4.5   True
# 23  466291                 tick, tick...BOOM!     4.5   True
#
#                                         link
# 1       /film/guillermo-del-toros-pinocchio/
# 2                       /film/the-menu-2022/
# 3    /film/glass-onion-a-knives-out-mystery/
# 4           /film/the-banshees-of-inisherin/
# 12                   /film/top-gun-maverick/
# 14                       /film/the-northman/
# 16  /film/everything-everywhere-all-at-once/
# 18                         /film/the-batman/
# 21               /film/west-side-story-2021/
# 23                /film/tick-tick-boom-2021/

# %%
# let's see my bottom 10 friends
df_friends.sort_values('total_index').head(10)
# Out:
#           username  index_score  no_of_movies  total_index
# 25      djdoublem3     0.480952            21        10.10
# 1   vonnysimarmata     0.565000            20        11.30
# 6      omarlae2106     0.421667            30        12.65
# 23     skipperjens     0.607143            21        12.75
# 18     ikiefriandi     0.593182            22        13.05
# 12      asddljhgfh     0.578261            23        13.30
# 24  kikyrahmannisa     0.593478            23        13.65
# 20    theorollason     0.503448            29        14.60
# 8          ccj6529     0.551724            29        16.00
# 10      jenniferrx     0.543333            30        16.30

# %% [markdown]
# # Creating Functions to Rank Movies
# - Notice that the function we created before stores the movie list of our friends inside friends_data, we need these to make movie recommendations
# - The main goal of this simple recommendation system is finding movie that's been rated and liked by our friends, our friends gave good rating on that movie, and if our closer friends rated that movies highly, it should have higher score

# %% [markdown]
# 4 attributes to be considered when ranking movies
# 1. Number of friends that have rated the movie
# 2. Number of friends that liked the movie
# 3. Ratings given by our friends on the movie
# 4. Friends index score so our closer friends' favorite movies will be ranked higher

# %%
def recommend_movies(df_friends, friends_data, df_a):
    df_movies = pd.DataFrame()

    # adding friends index score
    for i in friends_data.keys():
        df_friend_movies = friends_data[i]['df_b'].copy()
        df_friend_movies['friends_score'] = df_friends[df_friends['username'] == i]['total_index'].values[0]
        df_movies = pd.concat([df_movies, df_friend_movies])
        
    df_no_of_rate = pd.DataFrame(df_movies.id.value_counts()).reset_index()
    df_no_of_rate.rename({'index':'id', 'id':'no_of_rate'}, axis='columns', inplace=True)
    
    df_recom = df_movies.groupby(['id', 'title', 'link']).agg({'rating':'mean', 'liked':'sum', 'friends_score':'mean'})
    df_recom = df_recom.reset_index()
    df_recom = pd.merge(df_recom, df_no_of_rate)
    
    # excluding movies that we already watched
    df_recom = pd.merge(df_recom, df_a[['id']], how="outer", indicator=True)
    df_recom = df_recom[df_recom['_merge'] == 'left_only']
    del df_recom['_merge']

    # in this case, i use weights on the 4 attributes
    # you can customize the weights yourself, r_w is rating weight, l_w is liked weight, fs_w is friends score weight, nor_w is number of friends that rated the movie weight
    # i make the nor_w to 0 because I already use 'total_index' which is similarity score * number of friends that rated the movie, so basically i only use 3 of 4 attributes available
    # you can formulate your own calculation here
    r_w = 6
    l_w = 3
    fs_w = 2
    nor_w = 0
    df_recom['index'] = r_w/5*df_recom['rating']+l_w*df_recom['liked']/df_recom['liked'].max()+fs_w*df_recom['friends_score']/df_recom['friends_score'].max()+nor_w*df_recom['no_of_rate']/df_recom['no_of_rate'].max()
    return df_recom

# %%
# let's try it
df_recom = recommend_movies(df_friends, friends_data, df_a)

# %%
# let's see my top 10 recommendations
df_recom.sort_values('index', ascending=False).head(10)
# Out:
#           id                              title  \
# 702   293465                  Top Gun: Maverick
# 525   251943  Spider-Man: Into the Spider-Verse
# 1010  371378                               Dune
# 233   171384                           Whiplash
# 1300  422682                     Marriage Story
# 389   216086                     The Handmaiden
# 35    114564                                Her
# 2364   51896                    The Dark Knight
# 1387  433863                     The Lighthouse
# 954   359859                               Roma
#
#                                          link    rating  liked  friends_score  \
# 702                   /film/top-gun-maverick/  4.607143   11.0      21.121429
# 525   /film/spider-man-into-the-spider-verse/  4.562500   10.0      21.550000
# 1010                         /film/dune-2021/  4.175000   11.0      19.862500
# 233                      /film/whiplash-2014/  4.500000    8.0      22.240909
# 1300               /film/marriage-story-2019/  4.250000    9.0      22.404167
# 389                     /film/the-handmaiden/  4.916667    5.0      25.691667
# 35                                 /film/her/  4.208333    8.0      22.858333
# 2364                   /film/the-dark-knight/  4.555556    6.0      24.200000
# 1387               /film/the-lighthouse-2019/  4.300000    8.0      19.590000
# 954                          /film/roma-2018/  4.600000    6.0      21.350000
#
#       no_of_rate     index
# 702         14.0  9.771008
# 525         16.0  9.469920
# 1010        20.0  9.178382
# 233         11.0  8.890107
# 1300        12.0  8.872438
# 389          6.0  8.774911
# 35          12.0  8.576426
# 2364         9.0  8.526560
# 1387        15.0  8.494171
# 954         10.0  8.412246

# %% [markdown]
# ## Checkpoint 5
# - Looks like I need to watch Top Gun: Maverick because because it my friends rated it very highly, 11 of 14 liked it
# - I will try to explore more with advanced queries, for example I want movies that have index higher than 7.5, but unpopular (rated by not more than 7 but more than 2 friends)

# %%
df_recom[(df_recom['index']>7.5) & (df_recom['no_of_rate'] <= 8) & (df_recom['no_of_rate'] > 2)].sort_values('index', ascending=False).head(10)
# Out:
#           id               title                         link    rating  \
# 389   216086      The Handmaiden        /film/the-handmaiden/  4.916667
# 2457  532082           Chernobyl             /film/chernobyl/  4.750000
# 1451  441471     West Side Story  /film/west-side-story-2021/  4.750000
# 3007  668077  The Queen's Gambit     /film/the-queens-gambit/  4.250000
# 3109  695473                CODA             /film/coda-2021/  4.437500
# 2366   51902               Akira                 /film/akira/  4.750000
# 2443  527671          The Father       /film/the-father-2020/  4.357143
# 743   310705       The Favourite         /film/the-favourite/  4.250000
# 2351   51858              Amélie                /film/amelie/  4.666667
# 903   350384        The Big Sick          /film/the-big-sick/  4.833333
#
#       liked  friends_score  no_of_rate     index
# 389     5.0      25.691667         6.0  8.774911
# 2457    5.0      21.975000         6.0  8.356283
# 1451    5.0      20.408333         6.0  8.264127
# 3007    6.0      23.343750         8.0  8.109525
# 3109    5.0      20.456250         8.0  7.891945
# 2366    3.0      23.287500         4.0  7.888035
# 2443    5.0      22.000000         7.0  7.886325
# 743     5.0      23.887500         8.0  7.868783
# 2351    3.0      24.616667         3.0  7.866221
# 903     3.0      20.816667         3.0  7.842692

# %% [markdown]
# Voila! I will probably watch The Handmaiden next since it has an average ratings of 4.91 from 6 friends, with 5 likes

# %% [markdown]
# # Deployment with Streamlit
# I also deployed these functions to Streamlit web app, you can access it on https://letterboxd-friends-ranker.streamlit.app
# **Thank you!**
