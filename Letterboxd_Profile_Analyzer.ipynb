# %% [markdown]
# <a href="https://colab.research.google.com/github/ilmuneraka/letterboxd-friends-ranker/blob/main/Letterboxd_Profile_Analyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

DOMAIN = "https://letterboxd.com"

# %% [markdown]
# # Preparing Necessary Functions
# - We'll reuse some functions from my [previous notebook](https://colab.research.google.com/drive/1P1ApHz8nVAgaLlWcIz4kNnh6eq7DmHzS?usp=sharing)

# %%
def transform_ratings(some_str):
    """
    transforms raw star rating into float value
    :param: some_str: actual star rating
    :rtype: returns the float representation of the given star(s)
    """
    stars = {
        "★": 1,
        "★★": 2,
        "★★★": 3,
        "★★★★": 4,
        "★★★★★": 5,
        "½": 0.5,
        "★½": 1.5,
        "★★½": 2.5,
        "★★★½": 3.5,
        "★★★★½": 4.5
    }
    try:
        return stars[some_str]
    except:
        return -1

def scrape_films(username):
    movies_dict = {}
    movies_dict['id'] = []
    movies_dict['title'] = []
    movies_dict['rating'] = []
    movies_dict['liked'] = []
    movies_dict['link'] = []
    url = DOMAIN + "/" + username + "/films/"
    url_page = requests.get(url)
    soup = BeautifulSoup(url_page.content, 'html.parser')
    
    # check number of pages
    li_pagination = soup.findAll("li", {"class": "paginate-page"})
    if len(li_pagination) == 0:
        ul = soup.find("ul", {"class": "poster-list"})
        if (ul != None):
            movies = ul.find_all("li")
            for movie in movies:
                movies_dict['id'].append(movie.find('div')['data-film-id'])
                movies_dict['title'].append(movie.find('img')['alt'])
                movies_dict['rating'].append(transform_ratings(movie.find('p', {"class": "poster-viewingdata"}).get_text().strip()))
                movies_dict['liked'].append(movie.find('span', {'class': 'like'})!=None)
                movies_dict['link'].append(movie.find('div')['data-target-link'])
    else:
        for i in range(int(li_pagination[-1].find('a').get_text().strip())):
            url = DOMAIN + "/" + username + "/films/page/" + str(i+1)
            url_page = requests.get(url)
            soup = BeautifulSoup(url_page.content, 'html.parser')
            ul = soup.find("ul", {"class": "poster-list"})
            if (ul != None):
                movies = ul.find_all("li")
                for movie in movies:
                    movies_dict['id'].append(movie.find('div')['data-film-id'])
                    movies_dict['title'].append(movie.find('img')['alt'])
                    movies_dict['rating'].append(transform_ratings(movie.find('p', {"class": "poster-viewingdata"}).get_text().strip()))
                    movies_dict['liked'].append(movie.find('span', {'class': 'like'})!=None)
                    movies_dict['link'].append(movie.find('div')['data-target-link'])
    
    df_film = pd.DataFrame(movies_dict)    
    return df_film

# %% [markdown]
# # Getting The Movie Details
# As you can see from the scrape_films function, we only scrape
# - id
# - title
# - given rating
# - liked
# - link
#
# This is because the other details such as genres, actors are not accessible from one's profile page. So, we need to go to the movie's page to get those details.

# %%
# first, we need to take a look at the html of a movie's page
# for example, let's try to scrape the oscar winning movie Everything Everywhere All at Once (2022)

url = "https://letterboxd.com/film/everything-everywhere-all-at-once/"
url_page = requests.get(url)
soup = BeautifulSoup(url_page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7 ]> <html lang="en" class="ie6 lte9 lte8 lte7 lte6 no-js"> <![endif]-->
# <!--[if IE 7 ]>    <html lang="en" class="ie7 lte9 lte8 lte7 no-js"> <![endif]-->
# <!--[if IE 8 ]>    <html lang="en" class="ie8 lte9 lte8 no-js"> <![endif]-->
# <!--[if IE 9 ]>    <html lang="en" class="ie9 lte9 no-js"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--> <html class="no-mobile no-js" id="html" lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=1024" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="An aging Chinese immigrant is swept up in an insane adventure, where she alone can save what's important to her by connecting with the lives she could have led in other universes." name="description"/>
# <meta content="video.movie" property="og:type"/>
# <meta content="https://letterboxd.com/film/everything-everywhere-all-at-once/" property="og:url"/>
# <meta content="Everything Everywhere All at Once (2022)" property="og:title"/>
# <meta content="An aging Chinese immigrant is swept up in an insane adventure, where she alone can save what's important to her by connecting with the lives she could have led in other universes." property="og:description"/>
# <meta content="https://a.ltrbxd.com/resized/sm/upload/qo/9b/xq/hl/everything-1200-1200-675-675-crop-000000.jpg?v=59791ae192" property="og:image"/><meta content="1200" property="og:image:width"/><meta content="675" property="og:image:height"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@letterboxd" name="twitter:site"/><meta content="https://letterboxd.com/film/everything-everywhere-all-at-once/" name="twitter:url"/>
# <meta content="Everything Everywhere All at Once (2022)" name="twitter:title"/>
# <meta content="An aging Chinese immigrant is swept up in an insane adventure, where she alone can save what's important to her by connecting with the lives she could have led in other universes." name="twitter:description"/>
# <meta content="Directed by" name="twitter:label1"/><meta content="Daniel Scheinert, Daniel Kwan" name="twitter:data1"/>
# <meta content="Average rating" name="twitter:label2"/><meta content="4.42 out of 5" name="twitter:data2"/>
# <meta content="https://a.ltrbxd.com/resized/sm/upload/qo/9b/xq/hl/everything-1200-1200-675-675-crop-000000.jpg?v=59791ae192" name="twitter:image"/>
# <meta content="Letterboxd" name="application-name"/>
# <meta content="#445566" name="theme-color"/>
# <meta content="#445566" name="msapplication-TileColor"/>
# <meta content="app-id=1054271011, affiliate-data=11l5KW, app-argument=https://letterboxd.com/film/everything-everywhere-all-at-once/" name="apple-itunes-app"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <title>‎Everything Everywhere All at Once (2022) directed by Daniel Scheinert, Daniel Kwan • Reviews, film + cast • Letterboxd</title>
# <script>
# 		window.dataLayer = window.dataLayer || [];
# 		window.gtag = window.gtag || function () {
# 			dataLayer.push(arguments);
# 		};
# 		function ga() {}
# 	</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-D3ECBB4D7L"></script>
# <script>
# 		window.dataLayer = window.dataLayer || [];
# 		window.gtag = window.gtag || function () {
# 			dataLayer.push(arguments);
# 		};
# 		gtag('js', new Date());
#
# 		var analytic_params = {};
#
#
# 		analytic_params['user_type'] = 'Visitor';
# 		analytic_params['template'] = '/object/film';
#
#
# 				analytic_params['film_id'] = 'jUk4';
#
#
# 		if (analytic_params.member_type) {
# 			gtag('set', 'user_properties', {
# 				member_type: analytic_params.member_type,
# 			});
# 			delete analytic_params.member_type;
# 		}
# 		var config = {
# 			...analytic_params,
# 			'cookie_domain': 'letterboxd.com',
# 			'optimize_id': 'GTM-TB8HSDN',
# 		};
# 		gtag('config', 'G-D3ECBB4D7L', config);
# 	</script>
# <script>
# 		var isMobile = false,
# 			isMobileOptimised = true,
# 			renderMobile = false,
# 			useStaticFonts = false,
# 			disableFrameProtection = false,
# 			baseURL = "",
# 			successMessages = [],
# 			errorMessages = [],
# 			stickyMessages = [],
# 			globals = {
# 			autoAddFilm: false
# 				, spinners: {
# 					ajax_242d35: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.fda24f88.gif',
# 					spinner_12_2C3641: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.fda24f88.gif',
# 					spinner_14_20272f: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.fda24f88.gif',
# 					spinner_16_161B21: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.fda24f88.gif'
# 				}
# 			},
# 			supermodelCSRF = "",
# 			gRecaptchaKey = '6Le3mMIUAAAAAEXbwZ7M1R5jEv0V5xbvj7bgXq2g',
# 			person = {
# 				username: ""
# 				, loggedIn: false
#
# 				, showAds: true
# 				, role: "guest"
# 				, hasExtendedServiceFilters: false
# 				, canBulkAddToLists: false
# 				, canFilterOwned: false
# 				, hasHqRole: false
# 				, canHaveHqDashboard: false
# 				, hasMemberStatistics: false
# 				, blockedMembers: []
# 				, showAdultContent: false
# 				, validated: null
# 				, trusted: false
# 				, hasBlocked : function(member) { for (var i = 0; i !== person.blockedMembers.length; i++) {if (person.blockedMembers[i] === member) return true;} return false; }
# 				, viewingTags: []
# 				, hasMoreTags: true
# 				, getCustomPoster : function(filmId) { return null; }
# 			},
# 			disableAds = false;
#
#
#
# supermodelCSRF = "964c4ed3340c82cc54d6";
#
#
#
#
#
#
#
#
# 			if ( screen.width < 768 ) {
# 				var date = new Date();
# 				var maxAge = 365 * 24 * 60 * 60;
# 				date.setTime(date.getTime() + maxAge * 1000);
# 				var expires = '; expires=' + date.toUTCString();
# 				document.cookie = "useMobileSite=yes" + expires + "; path=/; maxAge=" + maxAge;
# 				if ( document.cookie && document.cookie.indexOf("useMobileSite=yes") >= 0 ) {
# 					window.location.reload(true);
# 				} else {
# 					// No cookies.  No Mobile version.
# 				}
# 			}
#
#
# 		var isWindows = navigator.platform.toUpperCase().indexOf('WIN') >= 0; // Detect windows platform
# 		if (isWindows) { document.documentElement.classList.add('is-windows'); }
#
#
# 			var filmData = { id: 474474, name: "Everything Everywhere All at Once", releaseYear: "2022", posterURL: "/film/everything-everywhere-all-at-once/image-150/", path: "/film/everything-everywhere-all-at-once/", runTime: 140 };
#
# 	</script>
# <script>
# 		window.ramp = window.ramp || {};
# 		window.ramp.que = window.ramp.que || [];
# 		window.ramp.passiveMode = false;
# 		window.ramp.forcePath = '';
# 		window.ramp.custom_tags = [
# 			'adventure',
# 			'action',
# 			'intl_false',
# 			'474474',
# 			''
# 		];
# 	</script>
# <script src="//cdn.intergient.com/1024338/72804/ramp_config.js"></script>
# <script>
# 		window._pwGA4PageviewId = ''.concat(Date.now());
# 		window.dataLayer = window.dataLayer || [];
# 		window.gtag = window.gtag || function () {
# 			dataLayer.push(arguments);
# 		};
# 		gtag('js', new Date());
# 		gtag('config', 'G-L0W7RDZXX3', { 'send_page_view': false });
# 		gtag(
# 			'event',
# 			'ramp_js',
# 			{
# 				'send_to': 'G-L0W7RDZXX3',
# 				'pageview_id': window._pwGA4PageviewId
# 			}
# 		);
# 	</script>
# <link href="/manifest.json" rel="manifest"/>
# <link href="/humans.txt" rel="author" type="text/plain"/>
# <link color="#445566" href="https://s.ltrbxd.com/static/img/icons/letterboxd-decal-l-16px.5fe24c7d.svg" rel="mask-icon"/>
# <link href="https://s.ltrbxd.com/static/img/icons/touch-icon-192x192.257b84e7.png" rel="shortcut icon" sizes="196x196"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/static/opensearch.xml" rel="search" title="Letterboxd" type="application/opensearchdescription+xml"/>
# <!--[if lte IE 9 ]>
# 		<link href="https://s.ltrbxd.com/static/css/ie9-1.min.b72b872e.css" rel="stylesheet" media="screen, projection"/>
# 		<link href="https://s.ltrbxd.com/static/css/ie9-2.min.1ceffbf4.css" rel="stylesheet" media="screen, projection"/>
# 	<![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <link href="https://s.ltrbxd.com/static/css/main.min.f18ea8c5.css" media="screen, projection" rel="stylesheet"/>
# <!--<![endif]-->
# <!--[if lte IE 6]><script>location.replace("/errors/ie6");</script><![endif]-->
# <!--[if IE 7]><script>location.replace("/errors/ie7");</script><![endif]-->
# <!--[if IE 8]><script>location.replace("/errors/ie8");</script><![endif]-->
# <!--[if IE 9]><script>location.replace("/errors/ie9");</script><![endif]-->
# <link href="https://s.ltrbxd.com/static/css/desktop.min.cfbe66c2.css" media="screen, projection" rel="stylesheet"/>
# <script src="https://s.ltrbxd.com/static/js/main.min.0940f103.js"></script>
# <script>
# 		if ( $.cookie("letterboxd.admin.signed.in") === person.username ) {
# 			successMessages.push("You are signed in as " + person.username);
# 			$(function(){$("#header, #content, body").css("background","#543");});
# 		}
# 	</script>
# </head>
# <body class="film backdropped eeaao-eye" data-tmdb-id="545611" data-tmdb-type="movie" data-type="film">
# <div class="backdrop-container"> <div class="backdrop-wrapper" data-backdrop="https://a.ltrbxd.com/resized/sm/upload/qo/9b/xq/hl/everything-1200-1200-675-675-crop-000000.jpg?v=59791ae192" data-backdrop2x="https://a.ltrbxd.com/resized/sm/upload/qo/9b/xq/hl/everything-1920-1920-1080-1080-crop-000000.jpg?v=59791ae192" data-backdropmobile="https://a.ltrbxd.com/resized/sm/upload/qo/9b/xq/hl/everything-960-960-540-540-crop-000000.jpg?v=59791ae192" data-offset="0" id="backdrop"> <div class="backdropplaceholder js-backdrop-placeholder" style='background-image: url("https://a.ltrbxd.com/resized/sm/upload/qo/9b/xq/hl/everything-48-48-27-27-crop.png?v=59791ae192"); background-position: center -0px;'></div> <div class="backdropimage js-backdrop-image" style="background-position: center -0px;"></div> <div class="backdropmask js-backdrop-fade"></div> </div> </div>
# <script>
# </script>
# <script>
# var mainMenu = [];
#
#
# 	mainMenu.push({
# 		"id": 1,
# 		"url": "/sign-in/",
# 		"name": "Sign In",
# 		"cssClassCode": "sign-in-menu",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": true,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 2,
# 		"url": "/create-account/",
# 		"name": "Create Account",
# 		"cssClassCode": "create-account-menu",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 3,
# 		"url": "/",
# 		"name": "Home",
# 		"cssClassCode": "person-home",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": true,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 4,
# 		"url": "/activity/",
# 		"name": "Activity",
# 		"cssClassCode": "main-nav-activity",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": true,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "Activity",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 5,
# 		"url": "/films/",
# 		"name": "Films",
# 		"cssClassCode": "films-page main-nav-films",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 6,
# 		"url": "/lists/",
# 		"name": "Lists",
# 		"cssClassCode": "lists-page main-nav-lists",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 7,
# 		"url": "/members/",
# 		"name": "Members",
# 		"cssClassCode": "main-nav-people",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 8,
# 		"url": "/journal/",
# 		"name": "Journal",
# 		"cssClassCode": "main-nav-journal",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 9,
# 		"url": "/search/",
# 		"name": "Search results",
# 		"cssClassCode": "",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": true,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
# </script>
# <header class="site-header js-hide-in-app" id="header">
# <div class="site-header-bg"></div>
# <section>
# <h1 class="site-logo"><a class="logo replace" href="/">Letterboxd — Your life in film</a></h1>
# <div class="react-component" data-component-class="globals.comps.NavComponent"></div>
# <form action="#" autocapitalize="off" autocorrect="off" class="signin signin-form js-header-signin-form js-signin" data-recaptcha-action="signin" data-url="/user/login.do" id="signin" method="post" novalidate="novalidate">
# <input name="__csrf" type="hidden" value="placeholder"/>
# <fieldset class="fieldset">
# <div class="fields">
# <div class="col">
# <label for="username">Username or Email</label>
# <input autocomplete="email" class="field signin-field" data-focus-control="signingIn" id="username" inputmode="email" name="username" tabindex="1" type="email" value=""/>
# </div>
# <div class="col">
# <label for="password">Password</label>
# <input autocomplete="current-password" class="field signin-field" id="password" name="password" tabindex="2" type="password" value=""/>
# </div>
# <div class="signin-actions">
# <label class="option-label -checkbox -small" for="remember">
# <input class="checkbox" id="remember" name="remember" tabindex="3" type="checkbox" value="true"/><i class="substitute"></i>
# <span class="focus">Remember<span class="mob-hide"> me</span></span>
# </label>
# <p class="reset" tabindex="5"><a class="reset-password-link" href="/user/request-password-reset" target="_top">Forgotten<span class="elongated"> password</span>?</a></p>
# </div>
# <div class="col buttons">
# <div class="button-container"><input class="button -action button-green" tabindex="4" type="submit" value="Sign in"/><i></i></div>
# <div class="close js-close-signin">×</div>
# </div>
# </div>
# </fieldset>
# <div class="errormessage" id="signin-message"></div>
# </form>
# <form action="/search/" autocorrect="off" class="js-search-form search-form" id="search" method="get">
# <input autocomplete="false" name="hidden" style="display:none;" type="text"/>
# <fieldset>
# <label class="hidden" for="search-q">Search:</label>
# <input class="field -borderless" data-lpignore="true" id="search-q" inputmode="search" name="q" type="text" value=""/>
# <input class="action" type="submit" value="Search"/>
# </fieldset>
# </form>
# </section>
# </header>
# <div class="site-body -backdrop" id="content">
# <div class="content-wrap">
# <div class="cols-3 overflow" id="film-page-wrapper">
# <div class="col-6 gutter-right-1 col-poster-large" id="js-poster-col">
# <div aria-hidden="true" hidden="">
# <div id="poster-large">
# <div class="really-lazy-load poster film-poster film-poster-474474" data-cache-busting-key="80fbb370" data-film-id="474474" data-film-slug="/film/everything-everywhere-all-at-once/" data-hide-tooltip="true" data-image-height="750" data-image-width="500" data-linked="unlinked" data-poster-url="/film/everything-everywhere-all-at-once/image-150/" data-target-link="/film/everything-everywhere-all-at-once/" data-target-link-target=""> <img alt="Everything Everywhere All at Once" class="image" height="750" src="https://s.ltrbxd.com/static/img/empty-poster-500.825678f0.png" width="500"/> <span class="frame"><span class="frame-title"></span></span> </div>
# </div>
# </div>
# <section class="poster-list -p230 -single no-hover el col">
# <a href="#poster-large" id="poster-zoom">
# <div class="really-lazy-load poster film-poster film-poster-474474" data-cache-busting-key="80fbb370" data-context="hero" data-film-id="474474" data-film-slug="/film/everything-everywhere-all-at-once/" data-hide-tooltip="true" data-image-height="345" data-image-width="230" data-linked="unlinked" data-poster-url="/film/everything-everywhere-all-at-once/image-150/" data-show-menu="true" data-target-link="/film/everything-everywhere-all-at-once/" data-target-link-target=""> <img alt="Everything Everywhere All at Once" class="image" height="345" src="https://s.ltrbxd.com/static/img/empty-poster-230.876e6b8e.png" width="230"/> <span class="frame"><span class="frame-title"></span></span> </div> <div class="js-serial-csi" data-on-load="" data-src="/esi/film/everything-everywhere-all-at-once/stats/"> <ul class="film-stats"> <li class="stat"><a class="has-icon icon-placeholder"> </a></li> </ul> </div>
# </a>
# </section>
# <div class="js-csi js-hide-in-app" data-on-load="csi-availability" data-src="/csi/film/everything-everywhere-all-at-once/availability/?esiAllowUser=true&amp;esiAllowCountry=true">
# <section class="watch-panel">
# <div class="header">
# <h3 class="title">Where to watch</h3>
# <p class="trailer-link js-watch-panel-trailer">
# <a class="play track-event js-video-zoom" data-track-category="Trailer" href="//www.youtube.com/embed/wxN1T1uxQ2g?rel=0&amp;wmode=transparent">
# <span class="name">Trailer</span>
# </a>
# </p>
# </div>
# <div id="watch">
# <div class="other">
# <span class="more"> </span>
# <a class="jw-branding" href="https://www.justwatch.com" rel="noopener noreferrer" target="_blank">JustWatch</a>
# </div>
# </div>
# </section>
# </div>
# <script id="script-6be31d02-b0e7-4ce9-8233-25e77ec2c5a2"> ((tag, target) => { if (!disableAds && person.showAds) { let pwUnit = document.createElement('div'); pwUnit.id = 'pw-6be31d02-b0e7-4ce9-8233-25e77ec2c5a2'; pwUnit.className = 'pw-div'; pwUnit.setAttribute('data-pw-' + (renderMobile ? 'mobi' : 'desk'), 'sky_btf'); let kicker = [ '<div class="upgrade-kicker -skyscraper js-hide-in-app">', '<button type="button" class="modaltrigger" data-bs-toggle="modal" data-bs-target="#remove-ads-modal">', 'Remove Ads', '<svg aria-hidden="true" width="7" height="7" xmlns="http://www.w3.org/2000/svg"><path d="m.5.5 6 6M6.5.5l-6 6" fill-rule="evenodd" stroke="#000"/></svg>', '</button>', '</div>' ].join(''); if (target) { target.insertAdjacentElement('beforeend', pwUnit); } else { tag.insertAdjacentElement('afterend', pwUnit); } window.addEventListener('DOMContentLoaded', (event) => { pwUnit.insertAdjacentHTML('afterend', kicker); window.ramp.que.push(function () { window.ramp.addTag('pw-6be31d02-b0e7-4ce9-8233-25e77ec2c5a2'); }); }, { once: true }); } tag.remove(); })(document.getElementById('script-6be31d02-b0e7-4ce9-8233-25e77ec2c5a2')); </script>
# </div>
# <div class="col-17">
# <section class="film-header-lockup -default" id="featured-film-header">
# <h1 class="headline-1 js-widont prettify">Everything Everywhere All at Once</h1>
# <p>
# <small class="number"><a href="/films/year/2022/">2022</a></small>
#
#
#
#
# 					Directed by <a href="/director/daniel-scheinert/"><span class="prettify">Daniel Scheinert</span></a>, <a href="/director/daniel-kwan-2/"><span class="prettify">Daniel Kwan</span></a>
# </p>
# </section>
# <section class="section col-10 col-main">
# <section>
# <div class="review body-text -prose -hero prettify">
# <h3 class="hidden">Synopsis</h3>
# <h4 class="tagline">The universe is so much bigger than you realize.</h4>
# <div class="truncate" data-truncate="450">
# <p>An aging Chinese immigrant is swept up in an insane adventure, where she alone can save what's important to her by connecting with the lives she could have led in other universes.</p>
# </div>
# </div>
# <script id="script-a373e187-d557-4430-a8ef-06d2d8fc8250"> ((tag, target) => { if (!disableAds && person.showAds) { let pwUnit = document.createElement('div'); pwUnit.id = 'pw-a373e187-d557-4430-a8ef-06d2d8fc8250'; pwUnit.className = 'pw-div -tile300x250 -alignleft'; pwUnit.setAttribute('data-pw-' + (renderMobile ? 'mobi' : 'desk'), 'med_rect_btf'); let kicker = [ '<div class="upgrade-kicker -alignleft -med_rect js-hide-in-app">', '<button type="button" class="modaltrigger" data-bs-toggle="modal" data-bs-target="#remove-ads-modal">', 'Remove Ads', '<svg aria-hidden="true" width="7" height="7" xmlns="http://www.w3.org/2000/svg"><path d="m.5.5 6 6M6.5.5l-6 6" fill-rule="evenodd" stroke="#000"/></svg>', '</button>', '</div>' ].join(''); if (target) { target.insertAdjacentElement('beforeend', pwUnit); } else { tag.insertAdjacentElement('afterend', pwUnit); } window.addEventListener('DOMContentLoaded', (event) => { pwUnit.insertAdjacentHTML('afterend', kicker); window.ramp.que.push(function () { window.ramp.addTag('pw-a373e187-d557-4430-a8ef-06d2d8fc8250'); }); }, { once: true }); } tag.remove(); })(document.getElementById('script-a373e187-d557-4430-a8ef-06d2d8fc8250')); </script>
# </section>
# <div data-selected-tab="" id="tabbed-content">
# <header>
# <ul>
# <li><a data-id="cast" href="/film/everything-everywhere-all-at-once/">Cast</a></li>
# <li><a data-id="crew" href="/film/everything-everywhere-all-at-once/crew/" id="crew">Crew</a></li>
# <li><a data-id="details" href="/film/everything-everywhere-all-at-once/details/">Details</a></li>
# <li><a data-id="genres" href="/film/everything-everywhere-all-at-once/genres/">Genres</a></li>
# </ul>
# </header>
# <div class="tabbed-content-block" id="tab-cast">
# <h3 class="hidden">Cast</h3>
# <div class="cast-list text-sluglist">
# <p>
# <a class="text-slug tooltip" href="/actor/michelle-yeoh/" title="Evelyn Wang">Michelle Yeoh</a> <a class="text-slug tooltip" href="/actor/ke-huy-quan/" title="Waymond Wang">Ke Huy Quan</a> <a class="text-slug tooltip" href="/actor/stephanie-hsu/" title="Joy Wang / Jobu Tupaki">Stephanie Hsu</a> <a class="text-slug tooltip" href="/actor/james-hong/" title="Gong Gong">James Hong</a> <a class="text-slug tooltip" href="/actor/jamie-lee-curtis/" title="Deirdre Beaubeirdra">Jamie Lee Curtis</a> <a class="text-slug tooltip" href="/actor/tallie-medel/" title="Becky Sregor">Tallie Medel</a> <a class="text-slug tooltip" href="/actor/jenny-slate/" title="Debbie the Dog Mom">Jenny Slate</a> <a class="text-slug tooltip" href="/actor/harry-shum-jr/" title="Chad">Harry Shum Jr.</a> <a class="text-slug tooltip" href="/actor/biff-wiff/" title="Rick">Biff Wiff</a> <a class="text-slug tooltip" href="/actor/anthony-molinari/" title="Police - Confetti">Anthony Molinari</a> <a class="text-slug tooltip" href="/actor/peter-banifaz/" title="Alpha RV Officer #1">Peter Banifaz</a> <a class="text-slug tooltip" href="/actor/audrey-wasilewski/" title="Alpha RV Officer #2">Audrey Wasilewski</a> <a class="text-slug tooltip" href="/actor/andy-le/" title="Alpha Jumper - Bigger Trophy">Andy Le</a> <a class="text-slug tooltip" href="/actor/brian-le/" title="Alpha Jumper - Trophy">Brian Le</a> <a class="text-slug tooltip" href="/actor/daniel-scheinert/" title="District Manager">Daniel Scheinert</a> <a class="text-slug tooltip" href="/actor/sunita-mani/" title="TV Musical - Queen">Sunita Mani</a> <a class="text-slug tooltip" href="/actor/aaron-lazar/" title="TV Musical - Soldier">Aaron Lazar</a> <a class="text-slug tooltip" href="/actor/li-jing-5/" title="Kung Fu Master">Li Jing</a> <a class="text-slug tooltip" href="/actor/panuvat-anthony-nanakornpanom/" title="Police - Luchador">Panuvat Anthony Nanakornpanom</a> <a class="text-slug tooltip" href="/actor/dylan-henry-lau/" title="Young Boy Waymond">Dylan Henry Lau</a> <a class="text-slug tooltip" href="/actor/michiko-nishiwaki/" title="Kung Fu Competitor / Co-Star">Michiko Nishiwaki</a> <a class="text-slug tooltip" href="/actor/cara-marie-chooljian/" title="Alpha Jumper - Jogger">Cara Marie Chooljian</a> <a class="text-slug tooltip" href="/actor/randall-archer/" title="Alpha Jumper - Edgelord">Randall Archer</a> <a class="text-slug tooltip" href="/actor/efka-kvaraciejus/" title="Alpha Jumper - SWAT">Efka Kvaraciejus</a> <a class="text-slug tooltip" href="/actor/neravana-cabral/" title="Security Guard">Neravana Cabral</a> <a class="text-slug tooltip" href="/actor/chelsey-goldsmith/" title="Security Guard">Chelsey Goldsmith</a> <a class="text-slug tooltip" href="/actor/craig-henningsen/" title="Security Guard">Craig Henningsen</a> <a class="text-slug tooltip" href="/actor/jason-hamer/" title="Raccacoonie Puppeteer">Jason Hamer</a> <a class="text-slug tooltip" href="/actor/timothy-ralston/" title="Raccacoonie Puppeteer">Timothy Ralston</a>
# <a class="text-slug" id="show-cast-overflow">Show All…</a>
# <span id="cast-overflow" style="display:none;">
# <a class="text-slug tooltip" href="/actor/hiroshi-yada/" title="Raccacoonie Puppeteer">Hiroshi Yada</a> <a class="text-slug tooltip" href="/actor/jane-lui/" title="Opera Evelyn (voice)">Jane Lui</a> <a class="text-slug tooltip" href="/actor/timothy-eulich/" title="Laundromat Police">Timothy Eulich</a> <a class="text-slug tooltip" href="/actor/boon-pin-koh/" title="Maternity Doctor">Boon Pin Koh</a> <a class="text-slug tooltip" href="/actor/randy-newman/" title="Raccacoonie (voice) (uncredited)">Randy Newman</a> <a class="text-slug tooltip" href="/actor/daniel-kwan-2/" title="Mugger (uncredited)">Daniel Kwan</a> <a class="text-slug tooltip" href="/actor/elle-alexander/" title="Lunch Lady (uncredited)">Elle Alexander</a> <a class="text-slug tooltip" href="/actor/emmett-ferguson/" title="Movie Theater Goer (uncredited)">Emmett Ferguson</a> <a class="text-slug tooltip" href="/actor/waymond-lee/" title="Chinese Choir / Movie Producer (uncredited)">Waymond Lee</a> <a class="text-slug tooltip" href="/actor/amanda-macleod/" title="Dominatrix (uncredited)">Amanda MacLeod</a> <a class="text-slug tooltip" href="/actor/pablo-ramos-1/" title="Pedestrian (uncredited)">Pablo Ramos</a> <a class="text-slug tooltip" href="/actor/dy-sao/" title="Chinese Choir (uncredited)">D.Y. Sao</a> <a class="text-slug tooltip" href="/actor/freya-fox/" title="Mei Li (uncredited)">Freya Fox</a>
# </span>
# </p>
# </div>
# </div>
# <div class="tabbed-content-block column-block -crewroles" id="tab-crew">
# <h3>
# <span class="crewrole -full">Directors</span>
# <span aria-hidden="true" class="crewrole -short">Directors</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/director/daniel-scheinert/">Daniel Scheinert</a> <a class="text-slug" href="/director/daniel-kwan-2/">Daniel Kwan</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Additional Directing</span>
# <span aria-hidden="true" class="crewrole -short">Add. Directing</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/additional-directing/john-nasraway/">John Nasraway</a> <a class="text-slug" href="/additional-directing/rod-smith-7/">Rod Smith</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Producers</span>
# <span aria-hidden="true" class="crewrole -short">Producers</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/producer/anthony-russo/">Anthony Russo</a> <a class="text-slug" href="/producer/joe-russo/">Joe Russo</a> <a class="text-slug" href="/producer/tim-headington/">Tim Headington</a> <a class="text-slug" href="/producer/daniel-scheinert/">Daniel Scheinert</a> <a class="text-slug" href="/producer/daniel-kwan-2/">Daniel Kwan</a> <a class="text-slug" href="/producer/mike-larocca/">Mike Larocca</a> <a class="text-slug" href="/producer/jonathan-wang-1/">Jonathan Wang</a> <a class="text-slug" href="/producer/jon-read/">Jon Read</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Executive Producers</span>
# <span aria-hidden="true" class="crewrole -short">Exec. Producers</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/executive-producer/tim-headington/">Tim Headington</a> <a class="text-slug" href="/executive-producer/josh-rudnick/">Josh Rudnick</a> <a class="text-slug" href="/executive-producer/theresa-steele-page/">Theresa Steele Page</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Writers</span>
# <span aria-hidden="true" class="crewrole -short">Writers</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/writer/daniel-scheinert/">Daniel Scheinert</a> <a class="text-slug" href="/writer/daniel-kwan-2/">Daniel Kwan</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Casting</span>
# <span aria-hidden="true" class="crewrole -short">Casting</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/casting/sarah-halley-finn/">Sarah Halley Finn</a> <a class="text-slug" href="/casting/djinous-rowling/">Djinous Rowling</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Editor</span>
# <span aria-hidden="true" class="crewrole -short">Editor</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/editor/paul-rogers-2/">Paul Rogers</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Cinematography</span>
# <span aria-hidden="true" class="crewrole -short">Cinematography</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/cinematography/larkin-seiple/">Larkin Seiple</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Additional Photography</span>
# <span aria-hidden="true" class="crewrole -short">Add. Photography</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/additional-photography/matt-ardine/">Matt Ardine</a> <a class="text-slug" href="/additional-photography/brian-tebbets/">Brian Tebbets</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Production Design</span>
# <span aria-hidden="true" class="crewrole -short">Production Design</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/production-design/jason-kisvarday/">Jason Kisvarday</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Art Direction</span>
# <span aria-hidden="true" class="crewrole -short">Art Direction</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/art-direction/amelia-brooke/">Amelia Brooke</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Set Decoration</span>
# <span aria-hidden="true" class="crewrole -short">Set Decoration</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/set-decoration/kelsi-ephraim/">Kelsi Ephraim</a> <a class="text-slug" href="/set-decoration/madelyn-wilkime/">Madelyn Wilkime</a> <a class="text-slug" href="/set-decoration/hunter-gorton/">Hunter Gorton</a> <a class="text-slug" href="/set-decoration/lia-burton/">Lia Burton</a> <a class="text-slug" href="/set-decoration/sierra-harbison/">Sierra Harbison</a> <a class="text-slug" href="/set-decoration/ian-lapidus/">Ian Lapidus</a> <a class="text-slug" href="/set-decoration/anne-stericker/">Anne Stericker</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Special Effects</span>
# <span aria-hidden="true" class="crewrole -short">Special Effects</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/special-effects/charlie-bruchez/">Charlie Bruchez</a> <a class="text-slug" href="/special-effects/jonathan-kombrinck/">Jonathan Kombrinck</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Visual Effects</span>
# <span aria-hidden="true" class="crewrole -short">Visual Effects</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/visual-effects/evan-halleck/">Evan Halleck</a> <a class="text-slug" href="/visual-effects/matthew-wauhkonen/">Matthew Wauhkonen</a> <a class="text-slug" href="/visual-effects/zak-stoltz/">Zak Stoltz</a> <a class="text-slug" href="/visual-effects/ethan-feldbau/">Ethan Feldbau</a> <a class="text-slug" href="/visual-effects/jeff-desom/">Jeff Desom</a> <a class="text-slug" href="/visual-effects/benjamin-brewer-1/">Benjamin Brewer</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Stunts</span>
# <span aria-hidden="true" class="crewrole -short">Stunts</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/stunts/narayana-cabral/">Narayana Cabral</a> <a class="text-slug" href="/stunts/elisabeth-p-carpenter/">Elisabeth P. Carpenter</a> <a class="text-slug" href="/stunts/alfred-hsing/">Alfred Hsing</a> <a class="text-slug" href="/stunts/panuvat-anthony-nanakornpanom/">Panuvat Anthony Nanakornpanom</a> <a class="text-slug" href="/stunts/craig-henningsen/">Craig Henningsen</a> <a class="text-slug" href="/stunts/timothy-eulich/">Timothy Eulich</a> <a class="text-slug" href="/stunts/kieran-oconnor/">Kieran O'Connor</a> <a class="text-slug" href="/stunts/dy-sao/">D.Y. Sao</a> <a class="text-slug" href="/stunts/chelsey-goldsmith/">Chelsey Goldsmith</a> <a class="text-slug" href="/stunts/gemma-nguyen/">Gemma Nguyen</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Composers</span>
# <span aria-hidden="true" class="crewrole -short">Composers</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/composer/ryan-lott/">Ryan Lott</a> <a class="text-slug" href="/composer/rafiq-bhatia/">Rafiq Bhatia</a> <a class="text-slug" href="/composer/ian-chang/">Ian Chang</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Songs</span>
# <span aria-hidden="true" class="crewrole -short">Songs</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/songs/mitski/">Mitski</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Sound</span>
# <span aria-hidden="true" class="crewrole -short">Sound</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/sound/randy-wilson-3/">Randy Wilson</a> <a class="text-slug" href="/sound/kailand-c-reilly/">Kailand C. Reilly</a> <a class="text-slug" href="/sound/andrew-twite/">Andrew Twite</a> <a class="text-slug" href="/sound/jason-charbonneau/">Jason Charbonneau</a> <a class="text-slug" href="/sound/brent-kiser/">Brent Kiser</a> <a class="text-slug" href="/sound/ian-chase/">Ian Chase</a> <a class="text-slug" href="/sound/jacob-flack/">Jacob Flack</a> <a class="text-slug" href="/sound/ron-mellegers/">Ron Mellegers</a> <a class="text-slug" href="/sound/alexandra-fehrman/">Alexandra Fehrman</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Costume Design</span>
# <span aria-hidden="true" class="crewrole -short">Costume Design</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/costume-design/shirley-kurata/">Shirley Kurata</a> <a class="text-slug" href="/costume-design/courtney-hess/">Courtney Hess</a> <a class="text-slug" href="/costume-design/lisa-russey/">Lisa Russey</a> <a class="text-slug" href="/costume-design/kristina-selby/">Kristina Selby</a> <a class="text-slug" href="/costume-design/andrea-tsanas/">Andrea Tsanas</a> <a class="text-slug" href="/costume-design/alex-woehrle/">Alex Woehrle</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Makeup</span>
# <span aria-hidden="true" class="crewrole -short">Makeup</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/makeup/dania-simental/">Dania Simental</a> <a class="text-slug" href="/makeup/michelle-chung/">Michelle Chung</a> <a class="text-slug" href="/makeup/christine-choi/">Christine Choi</a> <a class="text-slug" href="/makeup/abigail-bradley/">Abigail Bradley</a> <a class="text-slug" href="/makeup/hiro-yada/">Hiro Yada</a>
# </p>
# </div>
# <h3>
# <span class="crewrole -full">Hairstyling</span>
# <span aria-hidden="true" class="crewrole -short">Hairstyling</span>
# </h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/hairstyling/anissa-salazar/">Anissa Salazar</a> <a class="text-slug" href="/hairstyling/meghan-heaney/">Meghan Heaney</a>
# </p>
# </div>
# </div>
# <div class="tabbed-content-block column-block" id="tab-details">
# <h3><span>Studios</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/studio/agbo/">AGBO</a> <a class="text-slug" href="/studio/ley-line-entertainment/">Ley Line Entertainment</a> <a class="text-slug" href="/studio/year-of-the-rat-productions/">Year of the Rat Productions</a> <a class="text-slug" href="/studio/hotdog-hands-llc/">Hotdog Hands LLC</a> <a class="text-slug" href="/studio/a24/">A24</a> <a class="text-slug" href="/studio/iac-films/">IAC Films</a>
# </p>
# </div>
# <h3><span>Country</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/films/country/usa/">USA</a>
# </p>
# </div>
# <h3><span>Original Language</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/films/language/english/">English</a>
# </p>
# </div>
# <h3><span>Spoken Languages</span></h3>
# <div class="text-sluglist">
# <p>
# <a class="text-slug" href="/films/language/english/">English</a> <a class="text-slug" href="/films/language/cantonese/">Cantonese</a> <a class="text-slug" href="/films/language/chinese/">Chinese</a>
# </p>
# </div>
# <h3><span>Alternative Titles</span></h3>
# <div class="text-indentedlist">
# <p>
# 											הכל בכל מקום בבת אחת, Τα Πάντα Όλα, Viss visur vienlaikus, Tout, partout, tout à la fois, Усе завжди і водночас, Све у исто време, Tudo em Todo Lugar ao Mesmo Tempo, 媽的多重宇宙, 奇异女侠玩救宇宙, Todo en Todas Partes al Mismo Tiempo, Todo En Todas Partes Al Mismo Tiempo, Her şey Her Yerde Aynı Anda, 에브리씽 에브리웨어 올 앳 원스, Wszystko wszędzie naraz, 양자경의 더 모든 날 모든 순간, 瞬息全宇宙, Ամեն ինչ ամենուր Միանգամից
# 										</p>
# </div>
# </div>
# <div class="tabbed-content-block column-block" id="tab-genres">
# <h3><span>Genres</span></h3>
# <div class="text-sluglist capitalize">
# <p>
# <a class="text-slug" href="/films/genre/adventure/">adventure</a> <a class="text-slug" href="/films/genre/action/">action</a> <a class="text-slug" href="/films/genre/science-fiction/">science-fiction</a>
# </p>
# </div>
# <h3><span>Themes</span></h3>
# <div class="text-sluglist capitalize">
# <p>
# <a class="text-slug" href="/films/theme/relationship-comedy/by/best-match/">Relationship comedy</a> <a class="text-slug" href="/films/theme/epic-heroes/by/best-match/">Epic heroes</a>
# <a class="text-slug" href="/films/mini-theme/martial-arts-kung-fu-choreography-cool-or-action-packed/by/best-match/">martial arts, kung fu, choreography, cool or action-packed</a> <a class="text-slug" href="/films/mini-theme/quirky-humor-relationships-endearing-humorous/by/best-match/">comedy, relationships, funny, quirky or humor</a> <a class="text-slug" href="/films/mini-theme/jokes-humor-chuckles-crude-gag/by/best-match/">funny, comedy, humor, jokes or hilarious</a> <a class="text-slug" href="/films/mini-theme/spaceship-space-technology-future-destruction/by/best-match/">sci-fi, aliens, space, spaceship or earth</a> <a class="text-slug" href="/films/mini-theme/moving-sadness-beauty-tragic-heartbreaking/by/best-match/">emotion, emotional, moving, sadness or feelings</a>
# <a class="text-slug" href="/film/everything-everywhere-all-at-once/themes/">Show All…</a>
# </p>
# </div>
# </div>
# </div>
# <p class="text-link text-footer">
#
# 					140 mins
#
# 						More at
# 						<a class="micro-button track-event" data-track-action="IMDb" href="http://www.imdb.com/title/tt6710474/maindetails">IMDb</a>
# <a class="micro-button track-event" data-track-action="TMDb" href="https://www.themoviedb.org/movie/545611/">TMDb</a>
# <span class="block-flag-wrapper show-on-hover hide-when-logged-out"> <a class="block-or-report-flag report-link has-icon icon-16 icon-report tooltip" data-report-url="/ajax/film:474474/report-form" href="#" title="Report this film">Report this film</a> </span>
# </p>
# </section>
# <aside class="sidebar">
# <section class="actions-panel" id="userpanel">
# <ul class="js-actions-panel">
# <span class="js-csi" data-on-load="sidebar-user-actions" data-src="/csi/film/everything-everywhere-all-at-once/sidebar-user-actions/?esiAllowUser=true">
# </span>
# <li class="panel-sharing sharing-toggle js-actions-panel-sharing">
# <button aria-controls="sharing-toggle-body-474474" aria-expanded="false" class="trigger" type="button">Share</button>
# <div class="body" id="sharing-toggle-body-474474">
# <div class="urlgroup">
# <input id="url-field-474474" readonly="" spellcheck="false" type="text" value="https://boxd.it/jUk4"/><button class="button clipboardtrigger has-icon" data-clipboard-target="#url-field-474474" data-sharer-type="link">
# <span class="label">Copy URL to Clipboard</span>
# <span class="icon"></span>
# </button>
# </div>
# <a class="shareitem -link -twitter" data-sharer-type="twitter" href="https://twitter.com/intent/tweet?text=Everything%20Everywhere%20All%20at%20Once%20%282022%29%20on%20%40letterboxd%3A%20https%3A%2F%2Fboxd.it%2FjUk4" rel="noreferrer" title="Tweet a link">
# <span class="label">Tweet a link</span>
# <span class="icon"></span>
# </a>
# <a class="shareitem -link -facebook" data-sharer-type="facebook" href="https://www.facebook.com/dialog/feed?app_id=173683136069040&amp;display=popup&amp;link=https%3A%2F%2Fletterboxd.com%2Ffilm%2Feverything-everywhere-all-at-once%2F&amp;redirect_uri=https://letterboxd.com/facebook-share" rel="noreferrer" title="Share to Facebook">
# <span class="label">Share to Facebook</span>
# <span class="icon"></span>
# </a>
# </div>
# </li>
# </ul>
# </section>
# <div class="js-csi" data-on-load="" data-src="/csi/film/everything-everywhere-all-at-once/rating-histogram/">
# </div>
# </aside>
# <div class="js-csi" data-on-load="" data-src="/csi/film/everything-everywhere-all-at-once/friend-activity/?esiAllowUser=true">
# </div>
# <div class="js-csi" data-on-load="csi-film-news" data-src="/csi/film/everything-everywhere-all-at-once/news/?esiAllowUser=true&amp;esiAllowCountry=true">
# </div>
# <section class="film-recent-reviews -clear">
# <div class="js-csi" data-on-load="csi-friend-reviews" data-src="/csi/film/everything-everywhere-all-at-once/friend-reviews/?esiAllowUser=true">
# </div>
# <section class="film-reviews section" data-how-many="12" data-url="/ajax/everything-everywhere-all-at-once/popular-reviews/" id="popular-reviews">
# <h2 class="section-heading"><a href="/film/everything-everywhere-all-at-once/reviews/by/activity/">Popular reviews</a></h2>
# <a class="all-link" href="/film/everything-everywhere-all-at-once/reviews/by/activity/">More</a>
# <ul class="film-popular-review">
# <li class="film-detail" data-person="bowenyang" data-viewing-id="246941208"> <a class="avatar -a40" href="/bowenyang/"> <img alt="Bowen Yang" height="40" src="https://secure.gravatar.com/avatar/54558f74769c6fb167244bafbb3f265b?rating=PG&amp;size=80&amp;border=&amp;default=https%3A%2F%2Fs.ltrbxd.com%2Fstatic%2Fimg%2Favatar80.74798e0d.png" width="40"/> </a> <div class="film-detail-content"> <div class="attribution-block -large"> <p class="attribution"> <a class="context" href="/bowenyang/film/everything-everywhere-all-at-once/" title="Read Bowen Yang’s review"> Review by <strong class="name">Bowen Yang</strong> </a> <span class="rating -green rated-10"> ★★★★★ </span> <span class="content-metadata"> <a class="has-icon icon-comment icon-16 comment-count" href="/bowenyang/film/everything-everywhere-all-at-once/">98</a> </span> </p> </div> <div class="body-text -prose collapsible-text" data-full-text-url="/s/full-text/viewing:246941208/"> <p>this is one of the best things i’ve ever seen in my piece of shit life.</p> </div> <p class="like-link-target react-component -monotone" data-component-class="globals.comps.LikeLinkComponent" data-format="svg" data-likeable="true" data-likeable-name="review" data-likeable-uid="viewing:246941208" data-likes-page="/bowenyang/film/everything-everywhere-all-at-once/likes/" data-owner="bowenyang"> <span class="svg-action -like"></span> </p> </div> </li>
# <li class="film-detail" data-person="Kurstboy" data-viewing-id="249053071"> <a class="avatar -a40" href="/kurstboy/"> <img alt="kársten" height="40" src="https://a.ltrbxd.com/resized/avatar/twitter/4/9/0/4/5/7/shard/http___pbs.twimg.com_profile_images_1001935353740177414_9ZQ0Noe4-0-80-0-80-crop.jpg?v=2627a755b4" width="40"/> </a> <div class="film-detail-content"> <div class="attribution-block -large"> <p class="attribution"> <a class="context" href="/kurstboy/film/everything-everywhere-all-at-once/" title="Read kársten’s review"> Review by <strong class="name">kársten</strong> </a> <span class="rating -green rated-8"> ★★★★ </span> </p> </div> <div class="body-text -prose collapsible-text" data-full-text-url="/s/full-text/viewing:249053071/"> <p>easily one of the top 5 movies about taxes</p> </div> <p class="like-link-target react-component -monotone" data-component-class="globals.comps.LikeLinkComponent" data-format="svg" data-likeable="true" data-likeable-name="review" data-likeable-uid="viewing:249053071" data-likes-page="/kurstboy/film/everything-everywhere-all-at-once/likes/" data-owner="Kurstboy"> <span class="svg-action -like"></span> </p> </div> </li>
# <li class="film-detail" data-person="CosmonautMarkie" data-viewing-id="250825445"> <a class="avatar -a40" href="/cosmonautmarkie/"> <img alt="CosmonautMarkie" height="40" src="https://a.ltrbxd.com/resized/avatar/upload/4/0/7/3/3/4/7/shard/avtr-0-80-0-80-crop.jpg?v=72ca7a1e72" width="40"/> </a> <div class="film-detail-content"> <div class="attribution-block -large"> <p class="attribution"> <a class="context" href="/cosmonautmarkie/film/everything-everywhere-all-at-once/" title="Read CosmonautMarkie’s review"> Review by <strong class="name">CosmonautMarkie</strong> </a> <span class="rating -green rated-10"> ★★★★★ </span> <span class="content-metadata"> <a class="has-icon icon-comment icon-16 comment-count" href="/cosmonautmarkie/film/everything-everywhere-all-at-once/">358</a> </span> </p> </div> <div class="body-text -prose collapsible-text" data-full-text-url="/s/full-text/viewing:250825445/"> <p>Watch it and have fun before film Twitter tells you it’s overrated</p> </div> <p class="like-link-target react-component -monotone" data-component-class="globals.comps.LikeLinkComponent" data-format="svg" data-likeable="true" data-likeable-name="review" data-likeable-uid="viewing:250825445" data-likes-page="/cosmonautmarkie/film/everything-everywhere-all-at-once/likes/" data-owner="CosmonautMarkie"> <span class="svg-action -like"></span> </p> </div> </li>
# <li class="film-detail" data-person="ianwokeup" data-viewing-id="248526852"> <a class="avatar -a40" href="/ianwokeup/"> <img alt="ian" height="40" src="https://a.ltrbxd.com/resized/avatar/upload/1/0/5/0/4/7/6/shard/avtr-0-80-0-80-crop.jpg?v=ec989cd398" width="40"/> </a> <div class="film-detail-content"> <div class="attribution-block -large"> <p class="attribution"> <a class="context" href="/ianwokeup/film/everything-everywhere-all-at-once/" title="Read ian’s review"> Review by <strong class="name">ian</strong> </a> <span class="rating -green rated-9"> ★★★★½ </span> <span class="content-metadata"> <a class="has-icon icon-comment icon-16 comment-count" href="/ianwokeup/film/everything-everywhere-all-at-once/">38</a> </span> </p> </div> <div class="body-text -prose collapsible-text" data-full-text-url="/s/full-text/viewing:248526852/"> <p>rocks just made me cry</p> </div> <p class="like-link-target react-component -monotone" data-component-class="globals.comps.LikeLinkComponent" data-format="svg" data-likeable="true" data-likeable-name="review" data-likeable-uid="viewing:248526852" data-likes-page="/ianwokeup/film/everything-everywhere-all-at-once/likes/" data-owner="ianwokeup"> <span class="svg-action -like"></span> </p> </div> </li>
# <li class="film-detail" data-person="wes10" data-viewing-id="248810614"> <a class="avatar -a40" href="/wes10/"> <img alt="wes10" height="40" src="https://a.ltrbxd.com/resized/avatar/upload/1/3/4/8/3/5/5/shard/avtr-0-80-0-80-crop.jpg?v=dda18e972f" width="40"/> </a> <div class="film-detail-content"> <div class="attribution-block -large"> <p class="attribution"> <a class="context" href="/wes10/film/everything-everywhere-all-at-once/" title="Read wes10’s review"> Review by <strong class="name">wes10</strong> </a> <span class="rating -green rated-9"> ★★★★½ </span> </p> </div> <div class="body-text -prose collapsible-text" data-full-text-url="/s/full-text/viewing:248810614/"> <p>cutest husband in the world</p> </div> <p class="like-link-target react-component -monotone" data-component-class="globals.comps.LikeLinkComponent" data-format="svg" data-likeable="true" data-likeable-name="review" data-likeable-uid="viewing:248810614" data-likes-page="/wes10/film/everything-everywhere-all-at-once/likes/" data-owner="wes10"> <span class="svg-action -like"></span> </p> </div> </li>
# ...
# <span class="avatar -a72"> <img alt="Cinema Nova" height="72" src="https://a.ltrbxd.com/resized/avatar/upload/8/5/9/3/8/4/6/shard/avtr-0-144-0-144-crop.jpg?v=a07070e269" width="72"/> </span>
# <span class="story">Story by Cinema Nova</span>
# </a>
# </li>
# <li>
# <a class="watchedstate-avatar story tooltip" href="/theextracredits/story/the-2022-movie-draft-with-grierson-leitch/" title="Story by The Extra Credits">
# <span class="avatar -a72"> <img alt="The Extra Credits" height="72" src="https://a.ltrbxd.com/resized/avatar/upload/3/8/2/7/5/9/7/shard/avtr-0-144-0-144-crop.jpg?v=4f9db81da9" width="72"/> </span>
# <span class="story">Story by The Extra Credits</span>
# </a>
# </li>
# <li>
# <a class="watchedstate-avatar story tooltip" href="/crew/story/baftas-2023-the-complete-list-of-winners/" title="Story by Letterboxd">
# <span class="avatar -a72"> <img alt="Letterboxd" height="72" src="https://a.ltrbxd.com/resized/avatar/upload/3/2/0/1/2/shard/avtr-0-144-0-144-crop.jpg?v=a2177210db" width="72"/> </span>
# <span class="story">Story by Letterboxd</span>
# </a>
# </li>
# <li>
# <a class="watchedstate-avatar story tooltip" href="/crew/story/yes-madam-the-girls-on-tops-x-letterboxd/" title="Story by Letterboxd">
# <span class="avatar -a72"> <img alt="Letterboxd" height="72" src="https://a.ltrbxd.com/resized/avatar/upload/3/2/0/1/2/shard/avtr-0-144-0-144-crop.jpg?v=a2177210db" width="72"/> </span>
# <span class="story">Story by Letterboxd</span>
# </a>
# </li>
# <li>
# <a class="watchedstate-avatar story tooltip" href="/michtheater/story/whats-playing-this-week-feb-17-23/" title="Story by The Michigan Theater">
# <span class="avatar -a72"> <img alt="The Michigan Theater" height="72" src="https://a.ltrbxd.com/resized/avatar/upload/7/6/9/4/9/1/6/shard/avtr-0-144-0-144-crop.jpg?v=bc17dace66" width="72"/> </span>
# <span class="story">Story by The Michigan Theater</span>
# </a>
# </li>
# </ul>
# </section>
# <section class="section related-lists -clear">
# <div class="js-csi" data-on-load="csi-popular-lists" data-src="/csi/film/everything-everywhere-all-at-once/popular-lists/">
# </div>
# </section>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# </div>
# <footer class="page-footer js-page-footer js-hide-in-app" id="page-footer">
# <div class="content-wrap">
# <nav class="footer-nav js-footer-nav">
# <ul>
# <li><a href="/about/">About</a></li>
# <li><a href="/journal/">News</a></li>
# <li class="js-hide-in-app"><a href="/pro/">Pro</a></li>
# <li><a href="/apps/">Apps</a></li>
# <li><a href="https://apple.co/3TfzHVG" rel="noopener noreferrer" target="_blank">Podcast</a></li>
# <li><a href="/year-in-review/">Year in Review</a></li>
# <li><a href="/gift-guide/">Gift Guide</a></li>
# <li><a href="/welcome/">Help</a></li>
# <li><a href="/legal/terms-of-use/">Terms</a></li>
# <li><a href="/api-beta/">API</a></li>
# <li><a href="/contact/">Contact</a></li>
# </ul>
# </nav>
# <div class="socials">
# <nav class="social-service-list -inline">
# <div class="listitem -icononly">
# <a class="trigger tooltip" href="https://twitter.com/letterboxd" rel="noopener noreferrer" target="_blank" title="Letterboxd on Twitter">
# <svg aria-hidden="true" class="glyph" height="16" role="presentation" width="20" xmlns="http://www.w3.org/2000/svg"><path d="M17.96 4.51V4c.8-.56 1.49-1.28 2.04-2.1-.74.33-1.53.54-2.36.65.85-.5 1.5-1.3 1.8-2.24-.78.46-1.66.8-2.6.98a4.13 4.13 0 0 0-7.1 2.76c0 .31.04.62.1.92A11.72 11.72 0 0 1 1.38.74a3.99 3.99 0 0 0 1.28 5.4A4.2 4.2 0 0 1 .8 5.62v.06c0 1.95 1.42 3.59 3.29 3.96a4.06 4.06 0 0 1-1.85.07 4.1 4.1 0 0 0 3.83 2.8A8.32 8.32 0 0 1 0 14.2C1.8 15.33 3.97 16 6.28 16A11.5 11.5 0 0 0 17.96 4.51Z"></path></svg>
# <span class="label">Twitter</span>
# </a>
# </div>
# <div class="listitem -icononly">
# <a class="trigger tooltip" href="https://www.facebook.com/letterboxd" rel="noopener noreferrer" target="_blank" title="Letterboxd on Facebook">
# <svg aria-hidden="true" class="glyph" height="19" role="presentation" width="19" xmlns="http://www.w3.org/2000/svg"><path d="M9.5 0a9.5 9.5 0 0 0-1.48 18.89V12H5.6V9.25h2.42V7.41c0-2.38 1.41-3.7 3.58-3.7 1.04 0 2.13.19 2.13.19v2.33h-1.2c-1.18 0-1.54.74-1.54 1.49v1.53h2.63L13.2 12h-2.21v6.89A9.5 9.5 0 0 0 9.5 0Z"></path></svg>
# <span class="label">Facebook</span>
# </a>
# </div>
# <div class="listitem -icononly">
# <a class="trigger tooltip" href="https://www.instagram.com/letterboxd" rel="noopener noreferrer" target="_blank" title="Letterboxd on Instagram">
# <svg aria-hidden="true" class="glyph" height="20" role="presentation" width="20" xmlns="http://www.w3.org/2000/svg"><path d="M14.12.06c1.07.05 1.8.22 2.43.46.66.26 1.21.6 1.77 1.16.56.55.9 1.11 1.15 1.77.25.63.42 1.36.47 2.43.04.94.06 1.32.06 3.3v1.37c0 1.54 0 2.19-.03 2.77v.22l-.03.58a7.34 7.34 0 0 1-.47 2.43 4.9 4.9 0 0 1-1.15 1.77 4.9 4.9 0 0 1-1.77 1.16c-.64.24-1.36.41-2.43.46l-.61.03h-.23c-.5.02-1.06.03-2.21.03H9.2c-2 0-2.37-.02-3.32-.06a7.34 7.34 0 0 1-2.43-.46 4.9 4.9 0 0 1-1.77-1.16 4.9 4.9 0 0 1-1.16-1.77 7.34 7.34 0 0 1-.46-2.43l-.03-.61v-.2A60.9 60.9 0 0 1 0 11.5V8.75C0 7.7.01 7.17.03 6.7v-.2l.03-.61C.1 4.8.28 4.08.52 3.45a4.9 4.9 0 0 1 1.16-1.77A4.9 4.9 0 0 1 3.45.52 7.34 7.34 0 0 1 5.88.06l.61-.03h.2C7.12 0 7.6 0 8.5 0h2.74c1.62 0 2 .02 2.88.06ZM11.02 2H8.97c-1.7 0-2.05.02-2.92.06a5.4 5.4 0 0 0-1.82.33c-.45.18-.78.39-1.12.73-.34.34-.55.67-.73 1.12-.13.35-.3.86-.33 1.82C2.02 6.93 2 7.29 2 8.98v2.04c0 1.7.02 2.05.06 2.92.04.95.2 1.47.33 1.81.18.46.39.78.73 1.13.34.34.67.55 1.12.73.35.13.86.29 1.82.33.83.04 1.2.05 2.7.06h2.47c1.51 0 1.87-.02 2.71-.06a5.4 5.4 0 0 0 1.81-.33c.46-.18.78-.4 1.12-.73.35-.35.56-.67.73-1.13.14-.34.3-.86.34-1.8a49 49 0 0 0 .06-2.72V8.77a49 49 0 0 0-.06-2.71 5.4 5.4 0 0 0-.34-1.82 3.02 3.02 0 0 0-.73-1.12 3.02 3.02 0 0 0-1.12-.73 5.4 5.4 0 0 0-1.81-.33c-.88-.04-1.23-.06-2.93-.06ZM10 4.86a5.14 5.14 0 1 1 0 10.28 5.14 5.14 0 0 1 0-10.28ZM10 7a3 3 0 1 0 0 6 3 3 0 0 0 0-6Zm5.25-3.5a1.25 1.25 0 1 1 0 2.5 1.25 1.25 0 0 1 0-2.5Z"></path></svg>
# <span class="label">Instagram</span>
# </a>
# </div>
# <div class="listitem -icononly">
# <a class="trigger tooltip" href="https://www.youtube.com/letterboxdhq" rel="noopener noreferrer" target="_blank" title="Letterboxd on YouTube">
# <svg aria-hidden="true" class="glyph" height="16" role="presentation" width="23" xmlns="http://www.w3.org/2000/svg"><path d="M11.74 0c.61 0 2.33.02 4.11.08l.54.02c1.7.06 3.35.18 4.1.38a2.87 2.87 0 0 1 2.03 2.02c.45 1.67.48 5.04.48 5.46v.08c0 .42-.03 3.8-.48 5.46a2.87 2.87 0 0 1-2.03 2.02c-.75.2-2.4.32-4.1.38l-.54.02c-1.78.07-3.5.08-4.11.08H11.26c-.62 0-2.33-.01-4.11-.08l-.54-.02c-1.7-.06-3.36-.18-4.1-.38A2.87 2.87 0 0 1 .48 13.5C.04 11.9 0 8.68 0 8.1v-.2c0-.58.04-3.79.48-5.4A2.87 2.87 0 0 1 2.5.48c.74-.2 2.4-.32 4.1-.38l.54-.02C8.93.02 10.65 0 11.26 0ZM9 4.57v6.86L15 8 9 4.57Z"></path></svg>
# <span class="label">YouTube</span>
# </a>
# </div>
# <div class="listitem -icononly">
# <a class="trigger tooltip" href="https://www.tiktok.com/@letterboxd" rel="noopener noreferrer" target="_blank" title="Letterboxd on TikTok">
# <svg aria-hidden="true" class="glyph" height="18" role="presentation" width="17" xmlns="http://www.w3.org/2000/svg"><path d="M16.48 4.32a4.62 4.62 0 0 1-3.92-2.66A4.04 4.04 0 0 1 12.23 0H9.07v11.85c0 1.93-1.19 3.07-2.65 3.07a2.71 2.71 0 0 1-2.04-.9 2.57 2.57 0 0 1-.6-2.1 2.55 2.55 0 0 1 1.26-1.81 2.7 2.7 0 0 1 2.24-.21V6.77a5.92 5.92 0 0 0-4.08.86 5.7 5.7 0 0 0-2.15 2.55 5.53 5.53 0 0 0 1.26 6.16 5.86 5.86 0 0 0 6.33 1.23 5.78 5.78 0 0 0 2.6-2.08c.64-.94.98-2.03.98-3.15V5.96a7.74 7.74 0 0 0 4.25 1.25V4.32Z"></path></svg>
# <span class="label">TikTok</span>
# </a>
# </div>
# </nav>
# </div>
# <p class="copyright">
# 				© Letterboxd Limited. Made by <a class="mute" href="/crew/">fans</a> in Aotearoa New Zealand.
# 				<span class="nobr"><a class="mute" href="https://letterboxd.com/about/film-data/">Film data</a> from <a class="mute" href="https://www.themoviedb.org">TMDb</a>.
#
# 						<a class="mute mobile-site-switch" data-use-mobile-site="yes" href="#">Mobile site</a>.
#
# 	</span>
# <span class="recap" style="display:none"><br/>This site is protected by reCAPTCHA and the Google <a class="mute" href="https://policies.google.com/privacy" rel="noopener noreferrer" target="_blank">privacy policy</a> and <a class="mute" href="https://policies.google.com/terms" rel="noopener noreferrer" target="_blank">terms of service</a> apply.</span>
# </p>
# </div>
# </footer>
# <script type="application/ld+json">
# /* <![CDATA[ */
# {"image":"https://a.ltrbxd.com/resized/film-poster/4/7/4/4/7/4/474474-everything-everywhere-all-at-once-0-230-0-345-crop.jpg?v=281f1a041e","@type":"Movie","director":[{"@type":"Person","name":"Daniel Scheinert","sameAs":"/director/daniel-scheinert/"},{"@type":"Person","name":"Daniel Kwan","sameAs":"/director/daniel-kwan-2/"}],"dateModified":"2023-03-22","productionCompany":[{"@type":"Organization","name":"AGBO","sameAs":"/studio/agbo/"},{"@type":"Organization","name":"Ley Line Entertainment","sameAs":"/studio/ley-line-entertainment/"},{"@type":"Organization","name":"Year of the Rat Productions","sameAs":"/studio/year-of-the-rat-productions/"},{"@type":"Organization","name":"Hotdog Hands LLC","sameAs":"/studio/hotdog-hands-llc/"},{"@type":"Organization","name":"A24","sameAs":"/studio/a24/"},{"@type":"Organization","name":"IAC Films","sameAs":"/studio/iac-films/"}],"releasedEvent":[{"@type":"PublicationEvent","startDate":"2022"}],"@context":"http://schema.org","url":"https://letterboxd.com/film/everything-everywhere-all-at-once/","actors":[{"@type":"Person","name":"Michelle Yeoh","sameAs":"/actor/michelle-yeoh/"},{"@type":"Person","name":"Ke Huy Quan","sameAs":"/actor/ke-huy-quan/"},{"@type":"Person","name":"Stephanie Hsu","sameAs":"/actor/stephanie-hsu/"},{"@type":"Person","name":"James Hong","sameAs":"/actor/james-hong/"},{"@type":"Person","name":"Jamie Lee Curtis","sameAs":"/actor/jamie-lee-curtis/"},{"@type":"Person","name":"Tallie Medel","sameAs":"/actor/tallie-medel/"},{"@type":"Person","name":"Jenny Slate","sameAs":"/actor/jenny-slate/"},{"@type":"Person","name":"Harry Shum Jr.","sameAs":"/actor/harry-shum-jr/"},{"@type":"Person","name":"Biff Wiff","sameAs":"/actor/biff-wiff/"},{"@type":"Person","name":"Anthony Molinari","sameAs":"/actor/anthony-molinari/"},{"@type":"Person","name":"Peter Banifaz","sameAs":"/actor/peter-banifaz/"},{"@type":"Person","name":"Audrey Wasilewski","sameAs":"/actor/audrey-wasilewski/"},{"@type":"Person","name":"Andy Le","sameAs":"/actor/andy-le/"},{"@type":"Person","name":"Brian Le","sameAs":"/actor/brian-le/"},{"@type":"Person","name":"Daniel Scheinert","sameAs":"/actor/daniel-scheinert/"},{"@type":"Person","name":"Sunita Mani","sameAs":"/actor/sunita-mani/"},{"@type":"Person","name":"Aaron Lazar","sameAs":"/actor/aaron-lazar/"},{"@type":"Person","name":"Li Jing","sameAs":"/actor/li-jing-5/"},{"@type":"Person","name":"Panuvat Anthony Nanakornpanom","sameAs":"/actor/panuvat-anthony-nanakornpanom/"},{"@type":"Person","name":"Dylan Henry Lau","sameAs":"/actor/dylan-henry-lau/"},{"@type":"Person","name":"Michiko Nishiwaki","sameAs":"/actor/michiko-nishiwaki/"},{"@type":"Person","name":"Cara Marie Chooljian","sameAs":"/actor/cara-marie-chooljian/"},{"@type":"Person","name":"Randall Archer","sameAs":"/actor/randall-archer/"},{"@type":"Person","name":"Efka Kvaraciejus","sameAs":"/actor/efka-kvaraciejus/"},{"@type":"Person","name":"Neravana Cabral","sameAs":"/actor/neravana-cabral/"},{"@type":"Person","name":"Chelsey Goldsmith","sameAs":"/actor/chelsey-goldsmith/"},{"@type":"Person","name":"Craig Henningsen","sameAs":"/actor/craig-henningsen/"},{"@type":"Person","name":"Jason Hamer","sameAs":"/actor/jason-hamer/"},{"@type":"Person","name":"Timothy Ralston","sameAs":"/actor/timothy-ralston/"},{"@type":"Person","name":"Hiroshi Yada","sameAs":"/actor/hiroshi-yada/"},{"@type":"Person","name":"Jane Lui","sameAs":"/actor/jane-lui/"},{"@type":"Person","name":"Timothy Eulich","sameAs":"/actor/timothy-eulich/"},{"@type":"Person","name":"Boon Pin Koh","sameAs":"/actor/boon-pin-koh/"},{"@type":"Person","name":"Randy Newman","sameAs":"/actor/randy-newman/"},{"@type":"Person","name":"Daniel Kwan","sameAs":"/actor/daniel-kwan-2/"},{"@type":"Person","name":"Elle Alexander","sameAs":"/actor/elle-alexander/"},{"@type":"Person","name":"Emmett Ferguson","sameAs":"/actor/emmett-ferguson/"},{"@type":"Person","name":"Waymond Lee","sameAs":"/actor/waymond-lee/"},{"@type":"Person","name":"Amanda MacLeod","sameAs":"/actor/aman ...
# /* ]]> */
# </script>
# <div aria-hidden="true" aria-labelledby="remove-ads-modal-title" class="modal-neue fade" id="remove-ads-modal" tabindex="-1">
# <div class="modal-dialog -sm modal-dialog-centered">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title" id="remove-ads-modal-title">Upgrade to remove ads</h5>
# <button aria-label="Close" class="close" data-bs-dismiss="modal-neue" type="button">
# <svg class="glyph" height="16" width="16" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd" stroke="#000" stroke-linecap="round" stroke-width="2"><path d="m1 1 14 14M1 15 15 1"></path></g></svg>
# </button>
# </div>
# <div class="modal-body">
# <div class="body-text -hero">
# <p>Letterboxd is an independent service created by a small team, and we rely mostly on the support of our members to maintain our site and apps. Please consider upgrading to a <a href="/pro/">Pro account</a>—for less than a couple bucks a month, you’ll get cool additional features like all-time and annual stats pages (<a href="https://letterboxd.com/jack/stats/">example</a>), the ability to select (and filter by) your favorite streaming services, and no ads!</p>
# </div>
# </div>
# <div class="modal-footer">
# <a class="button -action button-action" href="/pro/">Learn more about Pro</a>
# </div>
# </div>
# </div>
# </div>
# <form action="" aria-hidden="true" aria-labelledby="poster-picker-modal-title" class="modal-neue fade poster-picker-modal" data-bs-backdrop="static" id="poster-picker-modal" method="post" novalidate="novalidate" role="dialog" tabindex="-1">
# <div class="modal-dialog -lg modal-dialog-centered modal-dialog-scrollable">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title" id="poster-picker-modal-title">Select your preferred poster</h5>
# <button aria-label="Close" class="close" data-bs-dismiss="modal-neue" type="button">
# <svg class="glyph" height="16" width="16" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd" stroke="#000" stroke-linecap="round" stroke-width="2"><path d="m1 1 14 14M1 15 15 1"></path></g></svg>
# </button>
# </div>
# <div class="modal-body">
# <div data-js-target="poster-picker" data-poster-picker-options='{"id": "5937cc96-10cd-44b5-89eb-5def151b0c1d"}' id="poster-picker-5937cc96-10cd-44b5-89eb-5def151b0c1d"></div>
# </div>
# <div class="modal-footer">
# <div class="poster-picker-note">
# <div class="body-text -small">
# <p>Posters are sourced from <a href="https://www.themoviedb.org" target="_blank">TMDb</a> and <a href="https://posteritati.com" target="_blank">Posteritati</a>, and appear for you and visitors to your profile and content, depending on settings. <a href="https://letterboxd.com/journal/posterity-custom-posters/" target="_blank">Learn more.</a></p>
# </div>
# </div>
# <div class="poster-picker-controls" data-poster-picker-controls-for="5937cc96-10cd-44b5-89eb-5def151b0c1d">
# <div class="modal-action-group -center">
# <button class="button -destructive" data-js-trigger="reset" disabled="" type="button"><span class="label">Reset poster</span></button>
# <button class="button -action" data-js-trigger="submit" disabled="" type="submit"><span class="label">Save<span class="mob-hide"> changes</span></span></button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# <script defer="" src="https://s.ltrbxd.com/static/js/partner-publishers.min.6fc86c8d.js"></script>
# </body>
# </html>
# <script>
#
# 	gtag('event', 'genre_view', {
# 		genre: 'adventure',
# 		transport_type: 'beacon',
# 	});
#
# 	gtag('event', 'genre_view', {
# 		genre: 'action',
# 		transport_type: 'beacon',
# 	});
#
# 	gtag('event', 'genre_view', {
# 		genre: 'science-fiction',
# 		transport_type: 'beacon',
# 	});
#
# </script>

# %% [markdown]
# Everything Everywhere All at Once (2022) Letterboxd page
# ![](https://drive.google.com/uc?export=view&id=14JiJGE38gm1-iqcIviAl2Oeymj6hvkN1)
#
# We will try to scrape:
# - Year
# - Director (could be multiple)
# - Cast (will be very likely multiple)
# - Average Rating
# - Number of watches
# - Number of likes
# - Genres (will be likely multiple)
#
# from this page, we could obtain the year, director, cast, avg rating, and genres
#
# the exact number of watches and likes need to be obtained from another page, try to find this 'film-stats' class, it will lead to /esi/film/everything-everywhere-all-at-once/stats/
#
# ## Organizing The Dataset
# As you know, a movie could be directed by more than one person, the cast will mostly consists of many people, and the genres of a movie could be multiple too. So, we will not store those details into one dataframe, we will store each multiple values column into a different dataframe with a key column, and we will join them into one once we need it, so it's basically some kind of relational database.
#
# I will call the original dataframe as df_rating and it stores single value columns that are year, average rating, number of watches, and number of likes. The director dataframe as df_director and the actor dataframe as df_actor. I'm putting this illustration below for a better understanding of the dataset scheme.
#
# ![](https://drive.google.com/uc?export=view&id=1Lq40gEWH0pu7IEir4UANWgPMQiLRni94)
#
# Actually, we can store those data into one table since we can store list into pandas dataframe, but I'm more comfortable this way so I will do it this way

# %%
# I will not give detailed steps to scrape each detail, I will give you my final function

# this function will take df_film produced by scrape_films function as input
# iterate the movies inside df_film to get all details from those movies
# and then return 4 different dataframes like shown above
def scrape_films_details(df_film):
    df_film = df_film[df_film['rating']!=-1].reset_index(drop=True)
    movies_rating = {}
    movies_rating['id'] = []
    movies_rating['avg_rating'] = []
    movies_rating['year'] = []
    movies_rating['watched_by'] = []
    movies_rating['liked_by'] = []
    
    movies_actor = {}
    movies_actor['id'] = []
    movies_actor['actor'] = []
    movies_actor['actor_link'] = []
    
    movies_director = {}
    movies_director['id'] = []
    movies_director['director'] = []
    movies_director['director_link'] = []
    
    movies_genre = {}
    movies_genre['id'] = []
    movies_genre['genre'] = []
    for link in df_film['link']:
        print('scraping details of '+df_film[df_film['link'] == link]['title'].values[0])
        
        id_movie = df_film[df_film['link'] == link]['id'].values[0]
        url_movie = DOMAIN + link
        url_movie_page = requests.get(url_movie)
        soup_movie = BeautifulSoup(url_movie_page.content, 'html.parser')
        for sc in soup_movie.findAll("script"):
            if sc.string != None:
                if "ratingValue" in sc.string:
                    rating = sc.string.split("ratingValue")[1].split(",")[0][2:]
                if "releaseYear" in sc.string:
                    year = sc.string.split("releaseYear")[1].split(",")[0][2:].replace('"','')
        url_stats = DOMAIN + "/esi" + link + "stats"
        url_stats_page = requests.get(url_stats)
        soup_stats = BeautifulSoup(url_stats_page.content, 'html.parser')
        watched_by = int(soup_stats.findAll('li')[0].find('a')['title'].replace(u'\xa0', u' ').split(" ")[2].replace(u',', u''))
        liked_by = int(soup_stats.findAll('li')[2].find('a')['title'].replace(u'\xa0', u' ').split(" ")[2].replace(u',', u''))
        movies_rating['id'].append(id_movie)
        movies_rating['avg_rating'].append(rating)
        movies_rating['year'].append(year)
        movies_rating['watched_by'].append(watched_by)
        movies_rating['liked_by'].append(liked_by)

        # finding the actors
        if (soup_movie.find('div', {'class':'cast-list'}) != None):
            for actor in soup_movie.find('div', {'class':'cast-list'}).findAll('a'):
                if actor.get_text().strip() != 'Show All…':
                    movies_actor['id'].append(id_movie)
                    movies_actor['actor'].append(actor.get_text().strip())
                    movies_actor['actor_link'].append(actor['href'])

        # finding the directors
        if (soup_movie.find('div', {'id':'tab-crew'}) != None):
            for director in soup_movie.find('div', {'id':'tab-crew'}).find('div').findAll('a'):
                movies_director['id'].append(id_movie)
                movies_director['director'].append(director.get_text().strip())
                movies_director['director_link'].append(director['href'])

        # finding the genres
        if (soup_movie.find('div', {'id':'tab-genres'}) != None):
            for genre in soup_movie.find('div', {'id':'tab-genres'}).find('div').findAll('a'):
                movies_genre['id'].append(id_movie)
                movies_genre['genre'].append(genre.get_text().strip())

    df_rating = pd.DataFrame(movies_rating)
    df_actor = pd.DataFrame(movies_actor)
    df_director = pd.DataFrame(movies_director)
    df_genre = pd.DataFrame(movies_genre)
    return df_rating, df_actor, df_director, df_genre

# %%
# let's try it
df_film = scrape_films('cacingpincang')

# %%
df_rating, df_actor, df_director, df_genre = scrape_films_details(df_film)
# Out:
# scraping details of A Man Called Otto
# scraping details of Puss in Boots: The Last Wish
# scraping details of The Menu
# scraping details of Glass Onion: A Knives Out Mystery
# scraping details of The Banshees of Inisherin
# scraping details of Stealing Raden Saleh
# scraping details of All or Nothing: Arsenal
# scraping details of Nope
# scraping details of Missing Home
# scraping details of Elvis
# scraping details of Men
# scraping details of Srimulat: Hil Yang Mustahal – Babak Pertama
# scraping details of Doctor Strange in the Multiverse of Madness
# scraping details of Sonic the Hedgehog 2
# scraping details of Everything Everywhere All at Once
# scraping details of The Batman
# scraping details of Neymar: The Perfect Chaos
# scraping details of Spider-Man: No Way Home
# scraping details of Nussa
# scraping details of Clickbait
# scraping details of Free Guy
# scraping details of The Suicide Squad
# scraping details of Red Rocket
# scraping details of Cruella
# scraping details of Wrath of Man
# scraping details of Mortal Kombat
# scraping details of Nobody
# scraping details of The Heartbreak Club
# scraping details of Borat Subsequent Moviefilm
# scraping details of BLACKPINK: Light Up the Sky
# scraping details of The East
# scraping details of Enola Holmes
# scraping details of I Care a Lot
# scraping details of The Devil All the Time
# scraping details of All or Nothing: Tottenham Hotspur
# scraping details of I'm Thinking of Ending Things
# scraping details of The SpongeBob Movie: Sponge on the Run
# scraping details of Backstreet Rookie
# scraping details of Scoob!
# scraping details of The Last Dance
# scraping details of The Hunt
# scraping details of Spenser Confidential
# scraping details of The Social Dilemma
# scraping details of Sonic the Hedgehog
# scraping details of Promising Young Woman
# scraping details of Bad Boys for Life
# scraping details of One Day We'll Talk About Today
# scraping details of Imperfect
# scraping details of 1917
# scraping details of The Gentlemen
# scraping details of The Queen of Black Magic
# scraping details of Impetigore
# scraping details of El Camino: A Breaking Bad Movie
# scraping details of Guns Akimbo
# scraping details of Jojo Rabbit
# scraping details of Knives Out
# scraping details of Joker
# scraping details of It Chapter Two
# scraping details of The Lion King
# scraping details of Midsommar
# scraping details of Toy Story 4
# scraping details of Deadwood: The Movie
# scraping details of Parasite
# scraping details of Once Upon a Time… in Hollywood
# scraping details of Chase
# scraping details of John Wick: Chapter 3 - Parabellum
# scraping details of The Highwaymen
# scraping details of Stuber
# scraping details of Us
# scraping details of Fighting with My Family
# scraping details of Polar
# scraping details of The Mule
# scraping details of Take the Ball, Pass the Ball
# scraping details of Ralph Breaks the Internet
# scraping details of Goosebumps 2: Haunted Halloween
# scraping details of The Head Hunter
# scraping details of Hotel Mumbai
# scraping details of Johnny English Strikes Again
# scraping details of The Old Man & the Gun
# scraping details of The Equalizer 2
# scraping details of Incredibles 2
# scraping details of The Professor
# scraping details of BlacKkKlansman
# scraping details of Deadpool 2
# scraping details of Rampage
# scraping details of Thunder Road
# scraping details of The Long Dumb Road
# scraping details of Hereditary
# scraping details of Because This Is My First Life
# scraping details of Satan's Slaves
# scraping details of Three Billboards Outside Ebbing, Missouri
# scraping details of The Hitman's Bodyguard
# scraping details of Logan Lucky
# scraping details of Dunkirk
# scraping details of Annabelle: Creation
# scraping details of Loving Vincent
# scraping details of The Villainess
# scraping details of Baby Driver
# scraping details of John Wick: Chapter 2
# scraping details of T2 Trainspotting
# scraping details of Get Out
# scraping details of A Dog's Purpose
# scraping details of The Invisible Guest
# scraping details of Hacksaw Ridge
# scraping details of La La Land
# scraping details of The Handmaiden
# scraping details of The Conjuring 2
# scraping details of The Nice Guys
# scraping details of Captain America: Civil War
# scraping details of Keanu
# scraping details of Don't Breathe
# scraping details of Kung Fu Panda 3
# scraping details of The Ridiculous 6
# scraping details of The Hateful Eight
# scraping details of Goosebumps
# scraping details of Prison School
# scraping details of Green Room
# scraping details of PK
# scraping details of Penguins of Madagascar
# scraping details of Interstellar
# scraping details of Annabelle
# scraping details of Gone Girl
# scraping details of John Wick
# scraping details of The Equalizer
# scraping details of Let's Be Cops
# scraping details of The Grand Budapest Hotel
# scraping details of The Babadook
# scraping details of The Secret Life of Walter Mitty
# scraping details of The Wolf of Wall Street
# scraping details of The Double
# scraping details of Rush
# scraping details of Prisoners
# scraping details of We're the Millers
# scraping details of The World's End
# scraping details of The Conjuring
# scraping details of Inside Llewyn Davis
# scraping details of Les Misérables
# scraping details of Django Unchained
# scraping details of Seven Psychopaths
# scraping details of Liberal Arts
# scraping details of Puss in Boots
# scraping details of Moneyball
# scraping details of Johnny English Reborn
# scraping details of Killer Joe
# scraping details of The Raid
# scraping details of The Guard
# scraping details of The Art of Getting By
# scraping details of Kung Fu Panda 2
# scraping details of The Social Network
# scraping details of Incendies
# scraping details of Death at a Funeral
# scraping details of Shutter Island
# scraping details of 3 Idiots
# scraping details of Black Dynamite
# scraping details of The Invention of Lying
# scraping details of A Serious Man
# scraping details of Valhalla Rising
# scraping details of The Hangover
# scraping details of Inglourious Basterds
# scraping details of Up
# scraping details of Watchmen
# scraping details of Yes Man
# scraping details of RockNRolla
# scraping details of Burn After Reading
# scraping details of Tropic Thunder
# scraping details of Kung Fu Panda
# scraping details of In Bruges
# scraping details of There Will Be Blood
# scraping details of Into the Wild
# scraping details of Ocean's Thirteen
# scraping details of No Country for Old Men
# scraping details of Hot Fuzz
# scraping details of Smokin' Aces
# scraping details of Idiocracy
# scraping details of Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan
# scraping details of Click
# scraping details of See No Evil
# scraping details of V for Vendetta
# scraping details of Kiss Kiss Bang Bang
# scraping details of Kicking & Screaming
# scraping details of Ocean's Twelve
# scraping details of Kill Bill: Vol. 2
# scraping details of Eternal Sunshine of the Spotless Mind
# scraping details of The Motorcycle Diaries
# scraping details of Big Fish
# scraping details of Kill Bill: Vol. 1
# scraping details of Matchstick Men
# scraping details of Bruce Almighty
# scraping details of Gangs of New York
# scraping details of The Pianist
# scraping details of City of God
# scraping details of Ali G Indahouse
# scraping details of A Beautiful Mind
# scraping details of Ocean's Eleven
# scraping details of Donnie Darko
# scraping details of Sexy Beast
# scraping details of The Way of the Gun
# scraping details of Memento
# scraping details of Snatch
# scraping details of Requiem for a Dream
# scraping details of American Psycho
# scraping details of The Green Mile
# scraping details of Fight Club
# scraping details of The Sixth Sense
# scraping details of Rush Hour
# scraping details of Lock, Stock and Two Smoking Barrels
# scraping details of Saving Private Ryan
# scraping details of The Truman Show
# scraping details of The Big Lebowski
# scraping details of Good Will Hunting
# scraping details of The Game
# scraping details of Taste of Cherry
# scraping details of L.A. Confidential
# scraping details of Grosse Pointe Blank
# scraping details of Fargo
# scraping details of Trainspotting
# scraping details of Se7en
# scraping details of Bad Boys
# scraping details of Love Letter
# scraping details of The Usual Suspects
# scraping details of The Shawshank Redemption
# scraping details of Natural Born Killers
# scraping details of Forrest Gump
# scraping details of Pulp Fiction
# scraping details of Schindler's List
# scraping details of Reservoir Dogs
# scraping details of The Silence of the Lambs
# scraping details of Dead Poets Society
# scraping details of A Fish Called Wanda
# scraping details of Full Metal Jacket
# scraping details of The King of Comedy
# scraping details of Network
# scraping details of Taxi Driver
# scraping details of The Good, the Bad and the Ugly
# scraping details of 12 Angry Men

# %%
df_rating.head()
# Out:
#        id avg_rating  year  watched_by  liked_by
# 0  842221       3.62  2022       51696     15296
# 1  242285       4.27  2022      591453    272760
# 2  521323       3.67  2022     1065110    330250
# 3  586723       3.65  2022     1206120    370656
# 4  598882        4.1  2022      623489    233470

# %%
# now if we want to know the title too, merge it with the df_film, like this
pd.merge(df_film, df_rating).head()
# Out:
#        id                              title  rating  liked  \
# 0  842221                  A Man Called Otto     4.0  False
# 1  242285       Puss in Boots: The Last Wish     5.0   True
# 2  521323                           The Menu     4.0  False
# 3  586723  Glass Onion: A Knives Out Mystery     4.0  False
# 4  598882          The Banshees of Inisherin     5.0   True
#
#                                       link avg_rating  year  watched_by  \
# 0                 /film/a-man-called-otto/       3.62  2022       51696
# 1       /film/puss-in-boots-the-last-wish/       4.27  2022      591453
# 2                     /film/the-menu-2022/       3.67  2022     1065110
# 3  /film/glass-onion-a-knives-out-mystery/       3.65  2022     1206120
# 4         /film/the-banshees-of-inisherin/        4.1  2022      623489
#
#    liked_by
# 0     15296
# 1    272760
# 2    330250
# 3    370656
# 4    233470

# %% [markdown]
# # Visualization & Analysis
# - Visualization is a good way to understand the data, in this case I will try to use Altair chart, not Matplotlib

# %%
import altair as alt

# %% [markdown]
# ## Year Movies were Released
# I want to know from what year my movies were released, the year span, what the oldest movie is

# %%
df_rating_merged = pd.merge(df_film, df_rating)

# %%
alt.Chart(df_rating_merged).mark_bar(tooltip=True).encode(
                alt.X("year:O", axis=alt.Axis(labelAngle=90)),
                y='count()',
                color=alt.Color('liked', scale=alt.Scale(domain=[True, False], range=["#ff8000", "#00b020"]))
            ).properties(
                    width=800,
                    height=300
                    )
# Out:
# alt.Chart(...)

# %%
df_rating_merged[df_rating_merged['year'] == '1957']
# Out:
#         id         title  rating  liked                 link avg_rating  year  \
# 234  51700  12 Angry Men     5.0  False  /film/12-angry-men/       4.52  1957
#
#      watched_by  liked_by
# 234      598862    226772

# %% [markdown]
# - Looks like I mostly watched movies that were released in 2019
# - I mostly liked movies from 2020
# - The oldest movie I've watched is 12 Angry Men which was released in 1957
# - Next, I want to see by the decade, so I will group the movies by decade and then visualize it

# %%
def decade_year(year):
    return str(int(year/10)*10)+"s"

df_rating_merged['decade'] = df_rating_merged.apply(lambda row: decade_year(int(row['year'])), axis=1)

# %%
alt.Chart(df_rating_merged).mark_bar(tooltip=True).encode(
                alt.X("decade:O", axis=alt.Axis(labelAngle=90)),
                y='count()',
                color=alt.Color('liked', scale=alt.Scale(domain=[True, False], range=["#ff8000", "#00b020"]))
                ).properties(
                    width=800,
                    height=300
                    )
# Out:
# alt.Chart(...)

# %% [markdown]
# - as expected, I mostly watched movies that were released in 2010s with 105 movies
# - unlike number of movies which peaked in 2010s, my number of likes peaked in 2000s (21 movies), I mostly liked movies from that decade

# %% [markdown]
# ## My Ratings Compared to the Average Ratings
# I want to know how my ratings compared to the other users' ratings
# - Did I give higher or lower ratings than the others?
# - Which movie that I differed most from the crowd?

# %%
# to see if I gave higher or lower
df_rating_merged['difference'] = df_rating_merged['rating'].astype(float)-df_rating_merged['avg_rating'].astype(float)

# absolute values to know how different my ratings are and to see which movie that I differed most from the crowd
df_rating_merged['difference_abs'] = abs(df_rating_merged['difference'])

# %%
print("On average, I gave higher/lower ratings by {} points".format(round(df_rating_merged['difference'].mean(), 2)))
print("On average, my ratings are different from other users by {} points".format(round(df_rating_merged['difference_abs'].mean(), 2)))
# Out:
# On average, I gave higher/lower ratings by 0.29 points
# On average, my ratings are different from other users by 0.51 points

# %% [markdown]
# - Looks like I gave slightly higher ratings than others by 0.29 points

# %%
# my average rating
print("I gave average rating of {} on {} movies, and I liked {} movies".format(round(df_rating_merged['rating'].mean() ,2), len(df_rating_merged), df_rating_merged['liked'].sum()))
# Out:
# I gave average rating of 3.89 on 235 movies, and I liked 70 movies

# %%
# top 5 movies with the biggest differences
df_rating_merged.sort_values('difference_abs', ascending=False).head()
# Out:
#          id                title  rating  liked                      link  \
# 112  278289     The Ridiculous 6     4.0  False   /film/the-ridiculous-6/
# 101  316316      A Dog's Purpose     5.0   True     /film/a-dogs-purpose/
# 179   46659  Kicking & Screaming     4.0  False  /film/kicking-screaming/
# 85   432335         Thunder Road     2.5  False  /film/thunder-road-2018/
# 149   18627            Incendies     3.0  False          /film/incendies/
#
#     avg_rating  year  watched_by  liked_by decade  difference  difference_abs
# 112       1.77  2015       51479      3443  2010s        2.23            2.23
# 101       3.27  2017       69302     11161  2010s        1.73            1.73
# 179        2.7  2005       58333      5805  2000s        1.30            1.30
# 85         3.8  2018       50834     16516  2010s       -1.30            1.30
# 149       4.28  2010      171297     61142  2010s       -1.28            1.28

# %% [markdown]
# Why people dislike The Ridiculous 6 though? I know it's stupid but it's still pretty much entertaining for a comedy movie

# %%
# now we will visualize it
alt.Chart(df_rating_merged).mark_bar(tooltip=True).encode(
                alt.X("rating:O", axis=alt.Axis(labelAngle=0)),
                y='count()',
                color=alt.Color('liked', scale=alt.Scale(domain=[True, False], range=["#ff8000", "#00b020"]))
            ).properties(
                    width=500,
                    height=300
                    )
# Out:
# alt.Chart(...)

# %%
alt.Chart(df_rating_merged).mark_bar(tooltip=True).encode(
                alt.X("avg_rating", bin=True, axis=alt.Axis(labelAngle=0)),
                y='count()',
                color=alt.Color('liked', scale=alt.Scale(domain=[True, False], range=["#ff8000", "#00b020"]))
            ).properties(
                    width=500,
                    height=300
                    )
# Out:
# alt.Chart(...)

# %% [markdown]
# - I mostly rated movies that have average ratings between 3.5 and 4
# - Now I wonder how is the correlation between my ratings and the average ratings, let's find it out

# %%
df_rating_merged['rating'].astype(float).corr(df_rating_merged['avg_rating'].astype(float))
# Out:
# 0.560793650054708

# %%
alt.Chart(df_rating_merged).mark_circle(size=60).encode(
    x='rating:Q',
    y='avg_rating:Q',
    color=alt.Color('liked', scale=alt.Scale(domain=[True, False], range=["#ff8000", "#00b020"])),
    tooltip=['title', 'year', 'rating', 'avg_rating', 'difference']
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Popularity of My Movies and are They Likeable Movies?
# - Note that we also scrape number of watches and likes from my movies, so we will use it to measure popularity and likeability
# - To measure likeability, I will use the like to watch ratio, how many users like the movie compared to the total watches (sum of likes/sum of watches)
# - I also want to know which movie is the least popular and the most popular, the least likeable and the most likeable

# %%
df_rating_merged['ltw_ratio'] = df_rating_merged['liked_by']/df_rating_merged['watched_by']

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
df_rating_merged[['watched_by', 'ltw_ratio']].describe()
# Out:
#        watched_by  ltw_ratio
# count     235.000    235.000
# mean   560558.323      0.252
# std    592909.134      0.099
# min       188.000      0.059
# 25%     74873.500      0.175
# 50%    372246.000      0.243
# 75%    853414.500      0.328
# max   2430366.000      0.578

# %% [markdown]
# - On average (mean), I watched movies that were watched by 560,011.285 users, and movies that were liked by 25.2% users
# - From the description above, we can see that the number of watches values are not balanced (the difference between the mean and the median is quite large) while ltw_ratio values are more balanced

# %%
# top 5 my most popular movies
df_rating_merged.sort_values('watched_by', ascending=False).head()
# Out:
#          id         title  rating  liked                    link avg_rating  \
# 62   426406      Parasite   4.500  False    /film/parasite-2019/       4.57
# 56   406775         Joker   4.000  False       /film/joker-2019/        3.9
# 202   51568    Fight Club   5.000   True       /film/fight-club/        4.3
# 223   51444  Pulp Fiction   4.000  False     /film/pulp-fiction/       4.29
# 55   475370    Knives Out   4.000  False  /film/knives-out-2019/       4.06
#
#      year  watched_by  liked_by decade  difference  difference_abs  ltw_ratio
# 62   2019     2430366   1404042  2010s      -0.070           0.070      0.578
# 56   2019     2400675    984940  2010s       0.100           0.100      0.410
# 202  1999     2234416    978300  1990s       0.700           0.700      0.438
# 223  1994     2173711    959883  1990s      -0.290           0.290      0.442
# 55   2019     2127610    962167  2010s      -0.060           0.060      0.452

# %%
# top 5 my least popular movies
df_rating_merged.sort_values('watched_by').head()
# Out:
#         id                                        title  rating  liked  \
# 64  532074                                        Chase   3.500  False
# 18  606030                                        Nussa   3.500  False
# 27  597511                          The Heartbreak Club   3.000  False
# 11  830325  Srimulat: Hil Yang Mustahal – Babak Pertama   4.000  False
# 37  763562                            Backstreet Rookie   3.500  False
#
#                                                link avg_rating  year  \
# 64                                /film/chase-2019/       2.33  2019
# 18                                     /film/nussa/       3.64  2021
# 27                       /film/the-heartbreak-club/       2.99  2021
# 11  /film/srimulat-hil-yang-mustahal-babak-pertama/       3.44  2022
# 37                         /film/backstreet-rookie/       3.02  2020
#
#     watched_by  liked_by decade  difference  difference_abs  ltw_ratio
# 64         188        11  2010s       1.170           1.170      0.059
# 18         434       103  2020s      -0.140           0.140      0.237
# 27         567        68  2020s       0.010           0.010      0.120
# 11         626       143  2020s       0.560           0.560      0.228
# 37        1708       228  2020s       0.480           0.480      0.133

# %% [markdown]
# - Note that there's 3 Indonesian movies in this list, it shows that there's still very few Indonesian Letterboxd users, because I think Nussa is not that obscure

# %%
# top 5 my most likeable movies
df_rating_merged.sort_values('ltw_ratio', ascending=False).head()
# Out:
#          id                              title  rating  liked  \
# 62   426406                           Parasite   4.500  False
# 14   474474  Everything Everywhere All at Once   4.500   True
# 1    242285       Puss in Boots: The Last Wish   5.000   True
# 55   475370                         Knives Out   4.000  False
# 100  353117                            Get Out   4.500   True
#
#                                          link avg_rating  year  watched_by  \
# 62                       /film/parasite-2019/       4.57  2019     2430366
# 14   /film/everything-everywhere-all-at-once/       4.42  2022     1527067
# 1          /film/puss-in-boots-the-last-wish/       4.27  2022      591453
# 55                     /film/knives-out-2019/       4.06  2019     2127610
# 100                       /film/get-out-2017/        4.2  2017     2081680
#
#      liked_by decade  difference  difference_abs  ltw_ratio
# 62    1404042  2010s      -0.070           0.070      0.578
# 14     780065  2020s       0.080           0.080      0.511
# 1      272760  2020s       0.730           0.730      0.461
# 55     962167  2010s      -0.060           0.060      0.452
# 100    934923  2010s       0.300           0.300      0.449

# %%
# top 5 my least likeable movies
df_rating_merged.sort_values('ltw_ratio').head()
# Out:
#          id             title  rating  liked                     link  \
# 64   532074             Chase   3.500  False        /film/chase-2019/
# 112  278289  The Ridiculous 6   4.000  False  /film/the-ridiculous-6/
# 120  174952         Annabelle   3.000  False         /film/annabelle/
# 176   46635       See No Evil   2.500  False  /film/see-no-evil-2006/
# 124  139348     Let's Be Cops   3.000  False      /film/lets-be-cops/
#
#     avg_rating  year  watched_by  liked_by decade  difference  difference_abs  \
# 64        2.33  2019         188        11  2010s       1.170           1.170
# 112       1.77  2015       51479      3443  2010s       2.230           2.230
# 120       2.43  2014      258962     18997  2010s       0.570           0.570
# 176       2.16  2006       14678      1140  2000s       0.340           0.340
# 124       2.56  2014       64350      5612  2010s       0.440           0.440
#
#      ltw_ratio
# 64       0.059
# 112      0.067
# 120      0.073
# 176      0.078
# 124      0.087

# %% [markdown]
# - We see some bad movies here
# - Now I'm curious about the correlation of avg_rating and the ltw_ratio, let's find out

# %%
df_rating_merged['avg_rating'].astype(float).corr(df_rating_merged['ltw_ratio'])
# Out:
# 0.8861304610658886

# %% [markdown]
# really high correlation!

# %%
alt.Chart(df_rating_merged).mark_circle(size=60).encode(
    x='ltw_ratio:Q',
    y='avg_rating:Q',
    color=alt.Color('liked', scale=alt.Scale(domain=[True, False], range=["#ff8000", "#00b020"])),
    tooltip=['title', 'year', 'rating', 'avg_rating', 'ltw_ratio']
).interactive()
# Out:
# alt.Chart(...)

# %%
# now I will try to make a graph based on popularity and likeability
# we will know less popular movies with high likeability and popular movies but low likeability
alt.Chart(df_rating_merged).mark_circle(size=60).encode(
    x='ltw_ratio:Q',
    y='watched_by:Q',
    color=alt.Color('liked', scale=alt.Scale(domain=[True, False], range=["#ff8000", "#00b020"])),
    tooltip=['title', 'year', 'rating', 'avg_rating', 'watched_by', 'ltw_ratio']
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# - since it's an interactive chart, try to zoom in on movies with more than 1 million watches, and you'll see that Incredibles 2 (2018) is my popular movie with the least likeability
# - now try to zoom in on less popular movies with number of watches below 200k and move right (more than 0.345 ltw_ratio), from there I find Incendies (2010), Taste of Cherry (1997), Love Letter (1995), and Missing Home (2022) as likeable and unpopular movies
# - now I will try to find a movie that I like with lowest ltw_ratio, it's Johnny English Reborn (2011), only about 9% users liked it
#
# for the next visualization, I will try to group popularity and likeability into 4 scale
#
# popularity is determined by number of watches.
# - <= 10,000 -> very obscure
# - 10,101 - 100,000 -> obscure
# - 100,001 - 1,000,000 -> popular
# - \> 1,000,000 -> very popular
#
# Likeability is determined by number of likes to number of watches ratio.
# - <= 0.1 -> rarely likeable
# - 0.1 - 0.2 -> sometimes likeable
# - 0.2 - 0.4 -> often likeable
# - \> 0.4 -> usually likeable

# %%
def classify_popularity(watched_by):
    if (watched_by <= 10000):
        return "1 - very obscure"
    elif (watched_by <= 100000):
        return "2 - obscure"
    elif (watched_by <= 1000000):
        return "3 - popular"
    else:
        return "4 - very popular"

def classify_likeability(ltw_ratio):
    if (ltw_ratio <= 0.1):
        return "1 - rarely likeable"
    elif (ltw_ratio <= 0.2):
        return "2 - sometimes likeable"
    elif (ltw_ratio <= 0.4):
        return "3 - often likeable"
    else:
        return "4 - usually likeable"

df_rating_merged['popularity'] = df_rating_merged.apply(lambda row: classify_popularity(row['watched_by']), axis=1)
df_rating_merged['likeability'] = df_rating_merged.apply(lambda row: classify_likeability(row['ltw_ratio']), axis=1)

# %%
# now we will visualize it
alt.Chart(df_rating_merged).mark_bar(tooltip=True).encode(
                alt.X("popularity:O", axis=alt.Axis(labelAngle=0)),
                y='count()',
                color=alt.Color('liked', scale=alt.Scale(domain=[True, False], range=["#ff8000", "#00b020"]))
            ).properties(
                    width=500,
                    height=300
                    )
# Out:
# alt.Chart(...)

# %%
# now we will visualize it
alt.Chart(df_rating_merged).mark_bar(tooltip=True).encode(
                alt.X("likeability:O", axis=alt.Axis(labelAngle=0)),
                y='count()',
                color=alt.Color('liked', scale=alt.Scale(domain=[True, False], range=["#ff8000", "#00b020"]))
            ).properties(
                    width=500,
                    height=300
                    )
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Directors & Actors
# Let's see which director and actor I watched most

# %%
df_director_merged = pd.merge(df_film, df_director)
df_actor_merged = pd.merge(df_film, df_actor)

# %%
# my top 10 most watched directors
df_director_merged['director'].value_counts().head(10)
# Out:
# Quentin Tarantino    8
# Joel Coen            6
# Guy Ritchie          5
# Martin Scorsese      5
# David Fincher        5
# Steven Soderbergh    4
# Martin McDonagh      4
# Ethan Coen           4
# Chad Stahelski       3
# Edgar Wright         3
# Name: director, dtype: int64

# %%
# my top 10 most watched actors
df_actor_merged['actor'].value_counts().head(10)
# Out:
# Brad Pitt            11
# Tom Hanks             7
# Andy García           7
# Samuel L. Jackson     7
# Matt Damon            7
# Keanu Reeves          6
# Eddie Marsan          6
# Jack Black            6
# Steve Buscemi         6
# Casey Affleck         6
# Name: actor, dtype: int64

# %% [markdown]
# - Wow, I didn't know I watched Quentin Tarantino movies that much
# - I also didn't realise I watched many movies starring Brad Pitt
# - Now, I want to see which director and actor with the highest rating

# %%
df_temp_director = pd.merge(df_director_merged.groupby(['director', 'director_link']).agg({'liked':'sum', 'rating':'mean'}).reset_index(),
                            df_director['director'].value_counts().reset_index().rename(columns = {'index':'director', 'director':'count'}))

# %%
df_temp_director.sort_values('count', ascending=False).head(10)
# Out:
#               director                 director_link  liked  rating  count
# 145  Quentin Tarantino  /director/quentin-tarantino/      3   4.438      8
# 92           Joel Coen          /director/joel-coen/      3   4.083      6
# 47       David Fincher      /director/david-fincher/      1   3.900      5
# 69         Guy Ritchie        /director/guy-ritchie/      2   3.900      5
# 120    Martin Scorsese    /director/martin-scorsese/      1   3.900      5
# 173  Steven Soderbergh  /director/steven-soderbergh/      0   3.625      4
# 119    Martin McDonagh    /director/martin-mcdonagh/      3   4.625      4
# 58          Ethan Coen         /director/ethan-coen/      2   4.125      4
# 54        Edgar Wright       /director/edgar-wright/      2   4.167      3
# 27      Chad Stahelski     /director/chad-stahelski/      0   3.833      3

# %%
df_temp_director.sort_values('liked', ascending=False).head(10)
# Out:
#               director                 director_link  liked  rating  count
# 92           Joel Coen          /director/joel-coen/      3   4.083      6
# 119    Martin McDonagh    /director/martin-mcdonagh/      3   4.625      4
# 145  Quentin Tarantino  /director/quentin-tarantino/      3   4.438      8
# 69         Guy Ritchie        /director/guy-ritchie/      2   3.900      5
# 54        Edgar Wright       /director/edgar-wright/      2   4.167      3
# 58          Ethan Coen         /director/ethan-coen/      2   4.125      4
# 82         Jeff Fowler        /director/jeff-fowler/      2   4.000      2
# 146    Rajkumar Hirani    /director/rajkumar-hirani/      2   4.750      2
# 70       Hannah Fidell      /director/hannah-fidell/      1   4.000      1
# 142         Peter Weir         /director/peter-weir/      1   4.500      2

# %% [markdown]
# - Among my most watched directors, the director which I gave the highest average rating is Martin McDonagh, well it's not surprising since I really like his works, it's a shame Banshees of Inisherin didn't win any Oscar this year :(
# - There are 3 directors which I liked 3 of their movies, I think this list confirmed that Martin McDonagh is my favorite director

# %%
df_temp_actor = pd.merge(df_actor_merged.groupby(['actor', 'actor_link']).agg({'liked':'sum', 'rating':'mean'}).reset_index(),
                            df_actor['actor'].value_counts().reset_index().rename(columns = {'index':'actor', 'actor':'count'}))

# %%
df_temp_actor.sort_values('count', ascending=False).head(10)
# Out:
#                   actor                actor_link  liked  rating  count
# 1141          Brad Pitt         /actor/brad-pitt/      5   4.091     11
# 8222  Samuel L. Jackson  /actor/samuel-l-jackson/      3   4.143      7
# 9113          Tom Hanks         /actor/tom-hanks/      2   4.214      7
# 530         Andy García       /actor/andy-garcia/      0   3.286      7
# 6264         Matt Damon        /actor/matt-damon/      0   3.857      7
# 3818         Jack Black      /actor/jack-black-1/      2   3.750      6
# 3551      Harvey Keitel     /actor/harvey-keitel/      1   4.167      6
# 5123       Keanu Reeves      /actor/keanu-reeves/      0   3.583      6
# 8691      Steve Buscemi     /actor/steve-buscemi/      2   4.250      6
# 1480      Casey Affleck     /actor/casey-affleck/      0   3.833      6

# %%
df_temp_actor.sort_values('liked', ascending=False).head(10)
# Out:
#                      actor                    actor_link  liked  rating  count
# 1141             Brad Pitt             /actor/brad-pitt/      5   4.091     11
# 4376            Jim Carrey            /actor/jim-carrey/      5   4.083      6
# 3590  Helena Bonham Carter  /actor/helena-bonham-carter/      4   4.625      4
# 8191          Sam Rockwell          /actor/sam-rockwell/      4   4.500      5
# 1361    Caleb Landry Jones    /actor/caleb-landry-jones/      3   4.375      4
# 8222     Samuel L. Jackson      /actor/samuel-l-jackson/      3   4.143      7
# 1886         Colin Farrell         /actor/colin-farrell/      3   4.400      5
# 8679          Stephen Root          /actor/stephen-root/      3   4.167      3
# 9554       Woody Harrelson       /actor/woody-harrelson/      3   4.300      5
# 1187       Brendan Gleeson       /actor/brendan-gleeson/      3   4.375      4

# %% [markdown]
# - It looks like I gave good ratings on movies starring Helena Bonham Carter, which I also liked all 4 movies starring her, she's really an amazing actress
# - I also like Jim Carrey so it's fair seeing him on top of this list

# %%
df_temp_director = df_temp_director.sort_values('count', ascending=False).reset_index(drop=True)
n_director = df_temp_director.iloc[9]['count']
df_temp_director = df_temp_director[df_temp_director['count']>=n_director]

# %%
# let's try to visualize it
base = alt.Chart(df_director_merged[df_director_merged['director'].isin(df_temp_director['director'])]).encode(
                    alt.Y("director", sort=df_temp_director['director'].tolist(), axis=alt.Axis(labelAngle=0))
                )
            
area = base.mark_bar(tooltip=True).encode(
    alt.X('count()',
        axis=alt.Axis(title='Count of Records')),
        color=alt.Color('liked', scale=alt.Scale(domain=[True, False], range=["#ff8000", "#00b020"]))
)
line = alt.Chart(df_temp_director).mark_line(interpolate='monotone').encode(
    alt.Y("director", sort=df_temp_director['director'].tolist(), axis=alt.Axis(labelAngle=0)),
    alt.X('rating', axis=alt.Axis(title='Average Rating', titleColor='#40bcf4'), scale=alt.Scale(zero=False)),
    color=alt.Color(value="#40bcf4"),
)
alt.layer(area, line).resolve_scale(
                x = 'independent'
)
# Out:
# alt.LayerChart(...)

# %%
df_temp_actor = df_temp_actor.sort_values('count', ascending=False).reset_index(drop=True)
n_actor = df_temp_actor.iloc[9]['count']
df_temp_actor = df_temp_actor[df_temp_actor['count']>=n_actor]

# %%
base = alt.Chart(df_actor_merged[df_actor_merged['actor'].isin(df_temp_actor['actor'])]).encode(
                    alt.Y("actor", sort=df_temp_actor['actor'].tolist(), axis=alt.Axis(labelAngle=0))
                )
            
area = base.mark_bar(tooltip=True).encode(
    alt.X('count()',
        axis=alt.Axis(title='Count of Records')),
        color=alt.Color('liked', scale=alt.Scale(domain=[True, False], range=["#ff8000", "#00b020"]))
)
line = alt.Chart(df_temp_actor).mark_line(interpolate='monotone').encode(
    alt.Y("actor", sort=df_temp_actor['actor'].tolist(), axis=alt.Axis(labelAngle=0)),
    alt.X('rating', axis=alt.Axis(title='Average Rating', titleColor='#40bcf4'), scale=alt.Scale(zero=False)),
    color=alt.Color(value="#40bcf4"),
)
alt.layer(area, line).resolve_scale(
                x = 'independent'
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Genres
# Let's find out which genre I watched most

# %%
df_genre_merged = pd.merge(df_film, df_genre)

# %%
df_genre['genre'].value_counts()
# Out:
# drama              112
# comedy              98
# thriller            76
# crime               76
# action              59
# adventure           34
# mystery             29
# horror              23
# family              19
# fantasy             17
# animation           15
# science-fiction     14
# romance             12
# war                 12
# history             11
# documentary          7
# western              5
# music                4
# tv-movie             1
# Name: genre, dtype: int64

# %% [markdown]
# - Turns out my most watched genre is drama, followed by comedy
# - Let's give the same treatment as actors & directors to see which genre has the highest rating and genre that I like the most

# %%
df_temp_genre = pd.merge(df_genre_merged.groupby(['genre']).agg({'liked':'sum', 'rating':'mean'}).reset_index(),
                            df_genre['genre'].value_counts().reset_index().rename(columns = {'index':'genre', 'genre':'count'}))

# %%
df_temp_genre.sort_values('rating', ascending=False)
# Out:
#               genre  liked  rating  count
# 9           history      3   4.227     11
# 18          western      2   4.200      5
# 17              war      4   4.125     12
# 11            music      0   4.125      4
# 6             drama     40   4.089    112
# 12          mystery     10   3.966     29
# 4             crime     23   3.928     76
# 14  science-fiction      5   3.893     14
# 3            comedy     37   3.893     98
# 15         thriller     21   3.849     76
# 13          romance      6   3.833     12
# 1         adventure     13   3.794     34
# 5       documentary      1   3.786      7
# 2         animation      4   3.767     15
# 0            action     15   3.737     59
# 7            family      6   3.737     19
# 8           fantasy      5   3.618     17
# 16         tv-movie      0   3.500      1
# 10           horror      3   3.478     23

# %% [markdown]
# - Well it's true that I don't really fancy horror movies for I find it's boring, so it's not surprising seeing horror at the bottom of the list

# %%
df_temp_genre.sort_values('liked', ascending=False)
# Out:
#               genre  liked  rating  count
# 6             drama     40   4.089    112
# 3            comedy     37   3.893     98
# 4             crime     23   3.928     76
# 15         thriller     21   3.849     76
# 0            action     15   3.737     59
# 1         adventure     13   3.794     34
# 12          mystery     10   3.966     29
# 13          romance      6   3.833     12
# 7            family      6   3.737     19
# 8           fantasy      5   3.618     17
# 14  science-fiction      5   3.893     14
# 2         animation      4   3.767     15
# 17              war      4   4.125     12
# 9           history      3   4.227     11
# 10           horror      3   3.478     23
# 18          western      2   4.200      5
# 5       documentary      1   3.786      7
# 11            music      0   4.125      4
# 16         tv-movie      0   3.500      1

# %%
df_temp_genre = df_temp_genre.sort_values('count', ascending=False).reset_index(drop=True)

# %%
base = alt.Chart(df_genre_merged[df_genre_merged['genre'].isin(df_temp_genre['genre'])]).encode(
                    alt.X("genre", sort=df_temp_genre['genre'].tolist(), axis=alt.Axis(labelAngle=90))
                )

area = base.mark_bar(tooltip=True).encode(
    alt.Y('count()',
        axis=alt.Axis(title='Count of Records')),
        color=alt.Color('liked', scale=alt.Scale(domain=[True, False], range=["#ff8000", "#00b020"]))
)

line = alt.Chart(df_temp_genre).mark_line(interpolate='monotone').encode(
        alt.X('genre', sort=df_temp_genre['genre'].tolist()),
        alt.Y('rating',
            axis=alt.Axis(title='Average Rating', titleColor='#40bcf4'), scale=alt.Scale(zero=False)),
            color=alt.Color(value="#40bcf4")
    )

alt.layer(area, line).resolve_scale(
                y = 'independent'
).properties(width=800,
             height=300)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Genre Combinations
# It's a common thing that a movie has multiple genres, so let's dig deeper into combinations of genre to get a more specific understanding of my movies

# %%
df_genre_combination = pd.DataFrame(columns=df_genre_merged.columns)
for i in range(len(df_temp_genre['genre'].tolist())):
    for j in range(i+1, len(df_temp_genre['genre'].tolist())):
        df_ha = df_genre_merged[(df_genre_merged['genre'] == df_temp_genre['genre'].tolist()[i]) | (df_genre_merged['genre'] == df_temp_genre['genre'].tolist()[j])]
        if len(df_ha) != 0:
            df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
            df_ha = df_ha[df_ha.duplicated('id')]
            df_genre_combination = pd.concat([df_genre_combination, df_ha]).reset_index(drop=True)
# Out:
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]
# <ipython-input-72-dd42723091d3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ha['genre'] = df_temp_genre['genre'].tolist()[i] + " & " + df_temp_genre['genre'].tolist()[j]

# %%
df_genre_combination['genre'].value_counts().head()
# Out:
# crime & thriller    43
# drama & comedy      36
# drama & crime       35
# drama & thriller    33
# comedy & crime      28
# Name: genre, dtype: int64

# %%
df_temp_comb = pd.merge(df_genre_combination.groupby(['genre']).agg({'liked':'sum', 'rating':'mean'}).reset_index(),
                        df_genre_combination['genre'].value_counts().reset_index().rename(columns = {'index':'genre', 'genre':'count'}))

# %%
df_temp_comb.sort_values('count', ascending=False).head(20)
# Out:
#                  genre liked  rating  count
# 39    crime & thriller    12   3.860     43
# 44      drama & comedy    13   4.125     36
# 45       drama & crime    13   4.014     35
# 55    drama & thriller    13   4.061     33
# 21      comedy & crime    11   3.929     28
# 33      crime & action     5   3.741     27
# 18     comedy & action    11   3.750     26
# 77   thriller & action     5   3.667     24
# 19  comedy & adventure    11   3.864     22
# 0   action & adventure     6   3.618     17
# 82  thriller & mystery     7   4.094     16
# 22     comedy & family     6   3.833     15
# 81   thriller & horror     2   3.464     14
# 11  adventure & family     5   3.821     14
# 58  family & animation     3   3.692     13
# 30   comedy & thriller     7   3.962     13
# 52     drama & mystery     5   4.000     12
# 49     drama & history     3   4.227     11
# 56         drama & war     4   4.182     11
# 20  comedy & animation     3   3.727     11

# %% [markdown]
# - Wow, it turns out my most watched genre combination is crime & thriller while drama & comedy is in the second place

# %%
df_temp_comb = df_temp_comb.sort_values('count', ascending=False).reset_index(drop=True)
n_genre = df_temp_comb.iloc[19]['count']
df_temp_comb = df_temp_comb[df_temp_comb['count']>=n_genre]

# %%
base = alt.Chart(df_genre_combination[df_genre_combination['genre'].isin(df_temp_comb['genre'])]).encode(
                        alt.X("genre", sort=df_temp_comb['genre'].tolist(), axis=alt.Axis(labelAngle=90))
                    )
area = base.mark_bar(tooltip=True).encode(
    alt.Y('count()',
        axis=alt.Axis(title='Count of Records')),
        color=alt.Color('liked', scale=alt.Scale(domain=[True, False], range=["#ff8000", "#00b020"]))
)
line = alt.Chart(df_temp_comb).mark_line(interpolate='monotone').encode(
        alt.X('genre', axis=alt.Axis(title='genre combination'), sort=df_temp_comb['genre'].tolist()),
        alt.Y('rating',
            axis=alt.Axis(title='Average Rating', titleColor='#40bcf4'), scale=alt.Scale(zero=False)),
            color=alt.Color(value="#40bcf4")
    )
alt.layer(area, line).resolve_scale(y = 'independent').properties(width=800, height=300)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# - horror once again appear with the lowest average rating among my top genre combinations, even when it's combined with thriller

# %% [markdown]
# # Deployment with Streamlit
# I also deployed these functions to a Streamlit web app so you can use it to get these analyses and visualizations
#
# Try it here
# https://letterboxd-friends-ranker.streamlit.app
